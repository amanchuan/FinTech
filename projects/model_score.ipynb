# %%
# global config

import os
import sys

parentdir = os.path.dirname(os.getcwd())
sys.path.insert(0, parentdir)

to_dir = '../data/example/'
if not os.path.exists(to_dir):
    os.makedirs(to_dir)

# %%
import numpy as np
import pandas as pd
from eda.desc_stats import show_desc
from eda.bin_iv_woe import cont_feature_bin,disc_feature_bin,woe_transform
from eda.data_preprocess import capping
from eda.feature_select import feature_select
import gc
import warnings
warnings.filterwarnings('ignore')

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# 样本准本

# %%
base_data = pd.read_csv('./data/input/wpqx_dq_variables.csv')
print(base_data.shape)
del base_data['Unnamed: 0']
cols = [i.split('.')[1] for i in base_data.columns]
base_data.columns = cols

base_data['create_date'] = base_data['create_date'].apply(lambda x:x[:7])

# label标签：due_fpd15,def_fpd15; due_mob2,def_mob2_30; due_mob3,def_mob3_30; due_mob6,def_mob6_30; 
def build_label(row):
    if row[1]==1:
        return 1
    elif row[1]==0 and row[0]==1:
        return 0
    else: 
        return 
# base_data['target'] = base_data[['due_mob2','def_mob2_30']].apply(build_label,axis=1)
base_data['target'] = base_data[['due_fpd15','def_fpd15']].apply(build_label,axis=1)
base_data = base_data[base_data['target'].notnull()].reset_index(drop=True)

feats = base_data.columns[24:-1].to_list()
jg_feats = pd.Series(feats)[pd.Series(map(lambda x:x[:2], feats))=='jg'].to_list()
bj_feats = pd.Series(feats)[pd.Series(map(lambda x:x[:2], feats))=='bj'].to_list()
br_feats = pd.Series(feats)[pd.Series(map(lambda x:x[:2], feats))=='br'].to_list()

cols = br_feats+['target']
base_data = base_data[cols]
base_data.shape
# Out:
# (185350, 2133)
# (23954, 426)

# %%
base_data = pd.read_pickle('../data/input/base_data.pkl')
print(base_data.shape)
base_data.head()
# Out:
# (29188, 1441)
#                        id ACAJ_ZCVA_BFVA_N2 ACAJ_ZCVC_BFVA_N2  \
# 1  2020091307524712366123                 0                 0
# 5  2020091309254489366392                 0                 0
# 6  2020091309255938267573                 0                 0
# 7  2020091309260832567276                 0                 0
# 8  2020091309262965666320                 0                 0
#
#   ACAJ_ZCVC_BFVG_N2 ACAN_ZBVA_XAVA_BBVD_N1 ACAN_ZBVA_XAVB_BBVD_N8  \
# 1                 0                      0                      0
# 5                 0                      0                      1
# 6                 0                      0                      0
# 7                 0                      0                      0
# 8                 0                      0                      0
#
#   ACAN_ZBVA_XAVF_BBVF_N6 ACAN_ZBVA_XAVR_BBVF_N9 ACAN_ZBVA_XAVU_BBVD_N3  \
# 1                      0                      0                      0
# 5                      0                      0                      0
# 6                      0                      0                      0
# 7                      0                      0                      0
# 8                      0                      0                      0
#
#   ACAN_ZBVA_XAVU_BBVF_N2  ... REPAY_SGBH_YMD REPAY_SGBI_YMD REPAY_SGBL_YMC  \
# 1                      0  ...              0              0              0
# 5                      0  ...              0              0              0
# 6                      0  ...              0              0              0
# 7                      0  ...              0              0              0
# 8                      0  ...              0              0              0
#
#   REPAY_SGBL_YMD REPAY_SGBM_MD REPAY_SGBQ_MD REPAY_SGBS_MD REPAY_TEAB_MB  \
# 1              0             0             0             0             0
# 5              0             0             0             1             0
# 6              0             0             0             4             0
# 7              0             0             0             0             0
# 8              0             0             0             0             0
#
#   REPAY_TEAF_MB target
# 1             0    0.0
# 5             0    0.0
# 6             0    0.0
# 7             0    0.0
# 8             0    1.0
#
# [5 rows x 1441 columns]

# %% [markdown]
# 第一步 描述性统计和数据预处理
#
# 1. 数据取值。有效值、无效值(空值标识、默认值标识)
# 2. 不考虑id的情况下，对数据进行去重，即只看特征和标签的重复情况。

# %%
THE_EMPTY_FLAG = [np.nan, 'null', 'NULL', -999, '-999', 9999, -9998]
TO_EMPTY_STATUS = np.nan
base_data.replace(THE_EMPTY_FLAG, TO_EMPTY_STATUS, inplace=True) # preprocess1: 缺失值标识

del base_data['id']

row_desc = show_desc(base_data, detail=True)
# row_desc.to_excel('./data/output/wpqx_br_fests_desc_stats.xlsx')
# Out:
# 原始数据集： (29188, 1440)
# 重复行数： 5
# 去重后数据集： (29183, 1440)
# 包含空值的字段个数： 88
# 数据类型分布： {dtype('O'): 2, dtype('float64'): 370, dtype('int64'): 1068}

# %%
base_data = base_data.drop_duplicates().reset_index(drop=True) # preprocess2: 特征+标签去重，不包括ID。
print(base_data.shape)

total_feats = base_data.columns.to_list()
total_feats.remove('target')

# del base_data['br_applyloanstr_createdate_onlycache']  # choose 2 删除日期字段
# total_feats.remove('br_applyloanstr_createdate_onlycache')

# base_data[total_feats] = base_data[total_feats].apply(capping) # preprocess2: 异常值处理
# Out:
# (29183, 1440)

# %%
import joblib
from model.metrics import acc_pre_recal_f1,pr_cover,roc_ks_cover
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.model_selection import train_test_split,GridSearchCV,RandomizedSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
import lightgbm as lgb
from scipy.stats import randint as sp_randint
from scipy.stats import uniform as sp_uniform
from sklearn.model_selection import KFold
import os

from utils.func import setRandomSeed
setRandomSeed(2022)

# %%
feat_selector = feature_select(base_data, total_feats, 'target', 2022)
feat_selector._filter_by_desc()
feat_selector.bins_and_iv(cont_bin='tree', dist_bin='value')
feat_selector._filter_by_bins_iv()
feat_selector._filter_by_corr()
feat_selector._filter_by_psi()
feat_selector._filter_by_vif()
# Out:
# 选择缺失值占比小于0.8且最大单一值占比小于0.9的特征：365个。剔除变量1074个。
# 选择分箱后IV大于等于0.02的特征：127个。剔除变量238个。
# 选择相关系数小于等于0.8的特征：110个。剔除变量17个。
# 选择PSI小于等于0.1的特征：110个。剔除变量0个。
# 选择VIF小于等于10的特征：104个。剔除变量6个。

# %%
base_data['target'].value_counts()/base_data['target'].value_counts().sum()
# Out:
# 0.0    0.882294
# 1.0    0.117706
# Name: target, dtype: float64

# %% [markdown]
# 建模
#
# 输出模型效果和模型文件

# %%
class AutoModelSearch(object):
    def __init__(self, feats, target, train, test):
        """
        在入模特征上进行建模、基于模型的特征筛选、评分卡构造、模型文档输出;
        前序步骤:特征预处理和特征筛选;
        """
        self.feats = feats
        self.target = target
        self.train,self.test = train,test

    def _search_lr_model(self,model):
        super_param = {
            'penalty':['l1','l2'],
            'C': [0.01, 0.1, 0.2, 0.5, 1],
            'class_weight': [{1: 1, 0: 1}, {1: 2, 0: 1}, {1: 3, 0: 1}, 'balanced'],
            }
        lr_search = GridSearchCV(
            estimator=model(random_state=2022, fit_intercept=True, solver='saga'),
            param_grid=super_param, cv=5, scoring='f1', n_jobs=-1, verbose=0)
        
        lr_search.fit(self.train[self.feats], self.train[self.target])
        print('逻辑模型最优得分 {0},\n最优参数{1}'.format(lr_search.best_score_,lr_search.best_params_))
        lr_model = model(C=lr_search.best_params_['C'], penalty=lr_search.best_params_['penalty'], solver='saga',
                                class_weight=lr_search.best_params_['class_weight'])
        lr_model.fit(self.train[self.feats], self.train[self.target])
        return lr_model

    def _search_dt_model(self,model):
        super_param = {
            'max_depth': np.arange(2,5,1),
            # 'class_weight': [{1: 1, 0: 1}, {1: 2, 0: 1}, {1: 3, 0: 1}],
            'class_weight': ['balanced'],
            'min_samples_leaf': [0.05],
            }
        tree_search = GridSearchCV(
            estimator=model(),
            param_grid=super_param, cv=5, scoring='f1', n_jobs=-1, verbose=0)
        tree_search.fit(self.train[self.feats], self.train[self.target])
        print('决策树模型最优得分 {0},\n最优参数{1}'.format(tree_search.best_score_,tree_search.best_params_))
        tree_model = model(max_depth = tree_search.best_params_['max_depth'],
            class_weight=tree_search.best_params_['class_weight'])
        tree_model.fit(self.train[self.feats], self.train[self.target])
        return tree_model

    def _learning_rate_010_decay_power_0995(current_iter):
        base_learning_rate = 0.1
        lr = base_learning_rate  * np.power(.995, current_iter)
        return lr if lr > 1e-3 else 1e-3
    
    def _search_lgbm_model(self):
        set_params = {
            'n_estimators': 200,
            'early_stopping_round': 50,
            'random_state': 2021,
            'n_jobs': 2,
            'class_weight': 'balanced'
        }
        search_params = {
            'max_depth': sp_randint(8, 32),                     # [2, 63]
            'num_leaves': sp_randint(32, 128),                  # [7, 4095]
            'bagging_fraction': sp_uniform(loc=0.4, scale=0.6), # als subsample、bagging。随机选择数据样本的比率，取值介于0-1之间的实数，默认为1。可以加速训练过程并降低过拟合。
            'feature_fraction': sp_uniform(loc=0.4, scale=0.6), # als colsample_bytree。用于在每棵树随机选择部分的特征集合，取值介于0-1之间的实数，默认为1。可以加速训练过程并降低过拟合。
            # 'feature_fraction_bynode': ,  # als colsample_bynode。用于每个树节点的特征选择，取值介于0-1之间，默认为1。
            # 'pos_bagging_fraction': ,  # 在bagging_fraction随机选择数据样本时，对正样本的选择比率为pos_samples * pos_bagging_fraction，取值介于0-1之间的实数，默认为1。需要和参数bagging_freq、neg_bagging_fraction同时使用。只能应用于二分类，可以抑制数据偏斜问题。别名包括：pos_sub_row、pos_subsample、pos_bagging。
            # 'neg_bagging_fraction': ,  # 类比于pos_bagging_fraction参数，作用于选择负样本neg_samples * neg_bagging_fraction个数，默认取值为1。当neg_bagging_fraction和pos_bagging_fraction都为1时，即为非平衡选择样本。如果指定平衡选择样本，那么bagging_fraction参数会被忽略。
            # 'bagging_freq': ,          # als subsample_freq。用于：指定的每K次迭代选择bagging_fraction样本，取值为整数K，默认为0。需要和参数bagging_fraction一起使用。
            'min_child_weight': sp_uniform(loc=0.01, scale=29), # [0.01, (sample size / 1000)] dataset-dependent and loss-dependent
            'min_child_samples': sp_randint(50, 200),
            'min_gain_to_split': sp_uniform(loc=0.2, scale=0.2), # als min_split_gain。最小分割收益，default is 0
            # 'lambda_l1': [1, 5, 10, 20, 50],   # als reg_alpha。 L1正则强度，默认为0
            # 'lambda_l2': [0, 1, 10],         # als reg_lambda。 L2正则强度，默认为0
            'lambda_l1': sp_randint(0, 50),   # als reg_alpha。 L1正则强度，默认为0
            'lambda_l2': sp_randint(0, 50),   # als reg_lambda。 L2正则强度，默认为0
        }
        clf = lgb.LGBMClassifier(**set_params)
        gs = RandomizedSearchCV(  #RandomizedSearchCV内部通过并行来提速。
                estimator=clf, 
                param_distributions=search_params,
                scoring='roc_auc',
                cv=5,
                verbose=1
                # refit=True,    # default True
                )
        gs.fit(self.train[self.feats], self.train[self.target], eval_set=(self.test[self.feats], self.test[self.target]))
        # print('Best score reached:', gs.best_score_)
        # print('Best params: ', gs.best_params_)
        best_params = gs.best_estimator_.get_params()
        clf = lgb.LGBMClassifier(**best_params)
        # clf.fit(self.train[self.feats], self.train[self.target], callbacks=[lgb.reset_parameter(learning_rate=_learning_rate_010_decay_power_0995)])
        return clf


    def model_search(self):
        """搜索ks、auc最高的模型"""
        cand_models = {
            'lr':LogisticRegression,
            'decision_tree':DecisionTreeClassifier,
            'lgbm':None
            }
        cand_models_metrics = {}
        # 所有的best_model均进行5折交叉看最后的预测值。
        for name,model in cand_models.items():
            if name=='lr':
                best_model = self._search_lr_model(model)
                print('{0} 模型最优指标：'.format(name))
                y_pred = best_model.predict(self.test[self.feats])
                y_pred_prob = best_model.predict_proba(self.test[self.feats])[:,1]
                y_true = self.test[self.target]
                acc,precision,recall,f1 = acc_pre_recal_f1(y_true, y_pred)
                auc, ks = roc_ks_cover(y_true, y_pred_prob)
                cand_models_metrics[best_model]= [auc, ks]

            elif name=='decision_tree':
                best_model = self._search_dt_model(model)
                print('{0} 模型最优指标：'.format(name))
                y_pred = best_model.predict(self.test[self.feats])
                y_pred_prob = best_model.predict_proba(self.test[self.feats])[:,1]
                y_true = self.test[self.target]
                acc,precision,recall,f1 = acc_pre_recal_f1(y_true, y_pred)
                auc, ks = roc_ks_cover(y_true, y_pred_prob)
                cand_models_metrics[best_model]= [auc, ks]

            elif name=='lgbm':
                best_model = self._search_lgbm_model()
                folds = KFold(n_splits=5, shuffle=True)
                nflod_train_preds = []
                nflod_valid_preds = np.zeros(self.train.shape[0])
                oof_preds = np.zeros(self.test.shape[0])
                # feature_importance_df = pd.DataFrame()
                for n_fold, (train_idx, valid_idx) in enumerate(folds.split(self.train)):
                    print(self.train.shape)
                    print(len(train_idx), len(valid_idx))
                    # best_model.fit(
                    #     self.train.loc[train_idx, self.feats], 
                    #     self.train.loc[train_idx, self.target],
                    #     eval_set=(self.train.loc[valid_idx, self.feats], self.train.loc[valid_idx, self.target]),
                    #     eval_metric='auc', verbose=False, early_stopping_rounds=200)
                    best_model.fit(
                        self.train.loc[train_idx, self.feats], 
                        self.train.loc[train_idx, self.target],
                        eval_set=(self.train.loc[valid_idx, self.feats], self.train.loc[valid_idx, self.target]),
                        eval_metric='auc', verbose=False)

                    train_pred = best_model.predict_proba(self.train.loc[train_idx, self.feats], 
                                                            num_iteration=best_model.best_iteration_)[:, 1]
                    nflod_valid_preds[valid_idx] = best_model.predict_proba(self.train.loc[valid_idx, self.feats], 
                                                                            num_iteration=best_model.best_iteration_)[:, 1]
                    oof_preds += best_model.predict_proba(self.test[self.feats],
                                                            num_iteration=best_model.best_iteration_)[:, 1]/folds.n_splits
                train_auc, train_ks = roc_ks_cover(self.train.loc[train_idx, self.target], train_pred)
                nflod_train_preds.append(train_auc)
                val_auc, val_ks = roc_ks_cover(self.train[self.target], nflod_valid_preds)
                test_auc, test_ks = roc_ks_cover(self.test[self.target], oof_preds)

                cand_models_metrics[best_model]= [test_auc, test_ks]
        
        # 按照KS取最高的一个模型
        cand_models_metrics = dict(sorted(cand_models_metrics.items(), key=lambda x:x[1][1], reverse=True))
        # print(cand_models_metrics)
        # return list(cand_models_metrics.keys())[0]
        self.best_model = list(cand_models_metrics.keys())[0]

# %%
# build input
cols = np.append(feat_selector.feats,feat_selector.target)
train,test = train_test_split(feat_selector.df[cols], test_size=0.3, random_state=2022)
train.reset_index(drop=True, inplace=True)
test.reset_index(drop=True, inplace=True)
train[feat_selector.feats] = woe_transform(train[feat_selector.feats], feat_selector.bin_iv_woe_df)
test[feat_selector.feats] = woe_transform(test[feat_selector.feats], feat_selector.bin_iv_woe_df)

# %%
auto_ml = AutoModelSearch(feat_selector.feats, feat_selector.target, train, test)
auto_ml.model_search()
# Out:
# 逻辑模型最优得分 0.27871282666338837,
# 最优参数{'C': 0.2, 'class_weight': 'balanced', 'penalty': 'l2'}
# lr 模型最优指标：
# 数据集上的混淆矩阵：
#          预测结果为正例  预测结果为反例
# 真实样本为正例     4508     3179
# 真实样本为反例      451      617
# ----------------------------------------
# 模型预测的正确率: 0.5853797829811537
# 模型的精准率： 0.16253951527924132
# 模型的召回率： 0.5777153558052435
# 模型的f1值： 0.2537006578947369
# roc取线: (auc值0.6154377934632576)
# ------------------------------------------------------------
# ks曲线: (ks值0.16921413603101498)
# 决策树模型最优得分 0.24055155843018947,
# 最优参数{'class_weight': 'balanced', 'max_depth': 4, 'min_samples_leaf': 0.05}
# decision_tree 模型最优指标：
# 数据集上的混淆矩阵：
#          预测结果为正例  预测结果为反例
# 真实样本为正例     3958     3729
# 真实样本为反例      393      675
# ----------------------------------------
# 模型预测的正确率: 0.5291833238149629
# 模型的精准率： 0.15326975476839236
# 模型的召回率： 0.6320224719101124
# 模型的f1值： 0.24671052631578946
# roc取线: (auc值0.5965058352810255)
# ------------------------------------------------------------
# ks曲线: (ks值0.14701263722155544)
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [LightGBM] [Warning] min_gain_to_split is set=0.3386864392910829, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=0.3386864392910829
# [LightGBM] [Warning] feature_fraction is set=0.8487835385101288, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8487835385101288
# [LightGBM] [Warning] bagging_fraction is set=0.7634888813192431, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7634888813192431
# [LightGBM] [Warning] lambda_l2 is set=39, reg_lambda=0.0 will be ignored. Current value: lambda_l2=39
# [LightGBM] [Warning] lambda_l1 is set=20, reg_alpha=0.0 will be ignored. Current value: lambda_l1=20
# [1]	valid_0's binary_logloss: 0.688641
# Training until validation scores don't improve for 50 rounds
# [2]	valid_0's binary_logloss: 0.68382
# [3]	valid_0's binary_logloss: 0.680794
# [4]	valid_0's binary_logloss: 0.676822
# [5]	valid_0's binary_logloss: 0.674098
# [6]	valid_0's binary_logloss: 0.670795
# [7]	valid_0's binary_logloss: 0.668359
# [8]	valid_0's binary_logloss: 0.665943
# [9]	valid_0's binary_logloss: 0.664182
# [10]	valid_0's binary_logloss: 0.662215
# [11]	valid_0's binary_logloss: 0.660271
# [12]	valid_0's binary_logloss: 0.657481
# [13]	valid_0's binary_logloss: 0.656055
# [14]	valid_0's binary_logloss: 0.654167
# [15]	valid_0's binary_logloss: 0.653214
# [16]	valid_0's binary_logloss: 0.652421
# [17]	valid_0's binary_logloss: 0.651641
# [18]	valid_0's binary_logloss: 0.648853
# [19]	valid_0's binary_logloss: 0.647618
# [20]	valid_0's binary_logloss: 0.646308
# [21]	valid_0's binary_logloss: 0.645559
# [22]	valid_0's binary_logloss: 0.644574
# [23]	valid_0's binary_logloss: 0.643094
# [24]	valid_0's binary_logloss: 0.642725
# [25]	valid_0's binary_logloss: 0.641189
# [26]	valid_0's binary_logloss: 0.639481
# [27]	valid_0's binary_logloss: 0.637993
# [28]	valid_0's binary_logloss: 0.637024
# [29]	valid_0's binary_logloss: 0.635991
# [30]	valid_0's binary_logloss: 0.633704
# [31]	valid_0's binary_logloss: 0.633092
# [32]	valid_0's binary_logloss: 0.631802
# [33]	valid_0's binary_logloss: 0.631513
# [34]	valid_0's binary_logloss: 0.630375
# [35]	valid_0's binary_logloss: 0.628622
# [36]	valid_0's binary_logloss: 0.627602
# [37]	valid_0's binary_logloss: 0.626657
# [38]	valid_0's binary_logloss: 0.625957
# [39]	valid_0's binary_logloss: 0.625314
# [40]	valid_0's binary_logloss: 0.625033
# [41]	valid_0's binary_logloss: 0.624783
# [42]	valid_0's binary_logloss: 0.624425
# [43]	valid_0's binary_logloss: 0.62307
# [44]	valid_0's binary_logloss: 0.622286
# [45]	valid_0's binary_logloss: 0.621386
# [46]	valid_0's binary_logloss: 0.620478
# [47]	valid_0's binary_logloss: 0.620055
# [48]	valid_0's binary_logloss: 0.619292
# [49]	valid_0's binary_logloss: 0.618816
# [50]	valid_0's binary_logloss: 0.617759
# [51]	valid_0's binary_logloss: 0.617208
# [52]	valid_0's binary_logloss: 0.6171
# [53]	valid_0's binary_logloss: 0.61703
# [54]	valid_0's binary_logloss: 0.616521
# [55]	valid_0's binary_logloss: 0.615737
# [56]	valid_0's binary_logloss: 0.614985
# [57]	valid_0's binary_logloss: 0.614214
# [58]	valid_0's binary_logloss: 0.612922
# [59]	valid_0's binary_logloss: 0.611779
# [60]	valid_0's binary_logloss: 0.611041
# [61]	valid_0's binary_logloss: 0.610436
# [62]	valid_0's binary_logloss: 0.609625
# [63]	valid_0's binary_logloss: 0.609841
# [64]	valid_0's binary_logloss: 0.609243
# [65]	valid_0's binary_logloss: 0.608472
# [66]	valid_0's binary_logloss: 0.607703
# [67]	valid_0's binary_logloss: 0.607714
# [68]	valid_0's binary_logloss: 0.60664
# [69]	valid_0's binary_logloss: 0.605689
# [70]	valid_0's binary_logloss: 0.604672
# [71]	valid_0's binary_logloss: 0.604257
# [72]	valid_0's binary_logloss: 0.604017
# [73]	valid_0's binary_logloss: 0.604085
# [74]	valid_0's binary_logloss: 0.603491
# [75]	valid_0's binary_logloss: 0.602806
# [76]	valid_0's binary_logloss: 0.602563
# [77]	valid_0's binary_logloss: 0.601737
# [78]	valid_0's binary_logloss: 0.601416
# [79]	valid_0's binary_logloss: 0.600596
# [80]	valid_0's binary_logloss: 0.60052
# [81]	valid_0's binary_logloss: 0.599982
# [82]	valid_0's binary_logloss: 0.599967
# [83]	valid_0's binary_logloss: 0.600006
# [84]	valid_0's binary_logloss: 0.599054
# [85]	valid_0's binary_logloss: 0.598777
# [86]	valid_0's binary_logloss: 0.597956
# [87]	valid_0's binary_logloss: 0.597372
# [88]	valid_0's binary_logloss: 0.596579
# [89]	valid_0's binary_logloss: 0.596434
# [90]	valid_0's binary_logloss: 0.59617
# [91]	valid_0's binary_logloss: 0.59614
# [92]	valid_0's binary_logloss: 0.595298
# [93]	valid_0's binary_logloss: 0.595608
# [94]	valid_0's binary_logloss: 0.595278
# [95]	valid_0's binary_logloss: 0.594922
# [96]	valid_0's binary_logloss: 0.594542
# [97]	valid_0's binary_logloss: 0.593961
# [98]	valid_0's binary_logloss: 0.59336
# [99]	valid_0's binary_logloss: 0.592828
# [100]	valid_0's binary_logloss: 0.592383
# [101]	valid_0's binary_logloss: 0.592409
# [102]	valid_0's binary_logloss: 0.592707
# [103]	valid_0's binary_logloss: 0.592317
# [104]	valid_0's binary_logloss: 0.591759
# [105]	valid_0's binary_logloss: 0.590995
# [106]	valid_0's binary_logloss: 0.590842
# [107]	valid_0's binary_logloss: 0.590869
# [108]	valid_0's binary_logloss: 0.590339
# [109]	valid_0's binary_logloss: 0.590259
# [110]	valid_0's binary_logloss: 0.590548
# [111]	valid_0's binary_logloss: 0.590333
# [112]	valid_0's binary_logloss: 0.589914
# [113]	valid_0's binary_logloss: 0.58949
# [114]	valid_0's binary_logloss: 0.589227
# [115]	valid_0's binary_logloss: 0.589187
# [116]	valid_0's binary_logloss: 0.588598
# [117]	valid_0's binary_logloss: 0.588286
# [118]	valid_0's binary_logloss: 0.58807
# [119]	valid_0's binary_logloss: 0.588087
# [120]	valid_0's binary_logloss: 0.587953
# [121]	valid_0's binary_logloss: 0.587323
# [122]	valid_0's binary_logloss: 0.586998
# [123]	valid_0's binary_logloss: 0.586929
# [124]	valid_0's binary_logloss: 0.586375
# [125]	valid_0's binary_logloss: 0.586074
# [126]	valid_0's binary_logloss: 0.585895
# [127]	valid_0's binary_logloss: 0.585806
# [128]	valid_0's binary_logloss: 0.586049
# [129]	valid_0's binary_logloss: 0.586056
# [130]	valid_0's binary_logloss: 0.585916
# [131]	valid_0's binary_logloss: 0.58583
# [132]	valid_0's binary_logloss: 0.585859
# [133]	valid_0's binary_logloss: 0.58568
# [134]	valid_0's binary_logloss: 0.585577
# [135]	valid_0's binary_logloss: 0.585361
# [136]	valid_0's binary_logloss: 0.58538
# [137]	valid_0's binary_logloss: 0.585097
# [138]	valid_0's binary_logloss: 0.584944
# [139]	valid_0's binary_logloss: 0.58447
# [140]	valid_0's binary_logloss: 0.584088
# [141]	valid_0's binary_logloss: 0.583854
# [142]	valid_0's binary_logloss: 0.583701
# [143]	valid_0's binary_logloss: 0.583776
# [144]	valid_0's binary_logloss: 0.583388
# [145]	valid_0's binary_logloss: 0.583666
# [146]	valid_0's binary_logloss: 0.583596
# [147]	valid_0's binary_logloss: 0.583274
# [148]	valid_0's binary_logloss: 0.583016
# [149]	valid_0's binary_logloss: 0.582947
# [150]	valid_0's binary_logloss: 0.582837
# [151]	valid_0's binary_logloss: 0.58252
# [152]	valid_0's binary_logloss: 0.582423
# [153]	valid_0's binary_logloss: 0.582219
# [154]	valid_0's binary_logloss: 0.581716
# [155]	valid_0's binary_logloss: 0.582113
# [156]	valid_0's binary_logloss: 0.582334
# [157]	valid_0's binary_logloss: 0.582481
# [158]	valid_0's binary_logloss: 0.582186
# [159]	valid_0's binary_logloss: 0.582034
# [160]	valid_0's binary_logloss: 0.58222
# [161]	valid_0's binary_logloss: 0.582129
# [162]	valid_0's binary_logloss: 0.582037
# [163]	valid_0's binary_logloss: 0.582208
# [164]	valid_0's binary_logloss: 0.582309
# [165]	valid_0's binary_logloss: 0.582086
# [166]	valid_0's binary_logloss: 0.581977
# [167]	valid_0's binary_logloss: 0.581892
# [168]	valid_0's binary_logloss: 0.581662
# [169]	valid_0's binary_logloss: 0.581584
# [170]	valid_0's binary_logloss: 0.581536
# [171]	valid_0's binary_logloss: 0.581536
# [172]	valid_0's binary_logloss: 0.581536
# [173]	valid_0's binary_logloss: 0.581493
# [174]	valid_0's binary_logloss: 0.581493
# [175]	valid_0's binary_logloss: 0.581493
# [176]	valid_0's binary_logloss: 0.581493
# [177]	valid_0's binary_logloss: 0.581493
# [178]	valid_0's binary_logloss: 0.581493
# [179]	valid_0's binary_logloss: 0.581493
# [180]	valid_0's binary_logloss: 0.581493
# [181]	valid_0's binary_logloss: 0.581493
# [182]	valid_0's binary_logloss: 0.581493
# [183]	valid_0's binary_logloss: 0.581493
# [184]	valid_0's binary_logloss: 0.581493
# [185]	valid_0's binary_logloss: 0.581493
# [186]	valid_0's binary_logloss: 0.581493
# [187]	valid_0's binary_logloss: 0.581493
# [188]	valid_0's binary_logloss: 0.581493
# [189]	valid_0's binary_logloss: 0.581493
# [190]	valid_0's binary_logloss: 0.581493
# [191]	valid_0's binary_logloss: 0.581493
# [192]	valid_0's binary_logloss: 0.581493
# [193]	valid_0's binary_logloss: 0.581493
# [194]	valid_0's binary_logloss: 0.581493
# [195]	valid_0's binary_logloss: 0.581493
# [196]	valid_0's binary_logloss: 0.581493
# [197]	valid_0's binary_logloss: 0.581493
# [198]	valid_0's binary_logloss: 0.581493
# [199]	valid_0's binary_logloss: 0.581493
# [200]	valid_0's binary_logloss: 0.581493
# Did not meet early stopping. Best iteration is:
# [173]	valid_0's binary_logloss: 0.581493
# [LightGBM] [Warning] min_gain_to_split is set=0.3386864392910829, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=0.3386864392910829
# [LightGBM] [Warning] feature_fraction is set=0.8487835385101288, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8487835385101288
# [LightGBM] [Warning] bagging_fraction is set=0.7634888813192431, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7634888813192431
# [LightGBM] [Warning] lambda_l2 is set=39, reg_lambda=0.0 will be ignored. Current value: lambda_l2=39
# [LightGBM] [Warning] lambda_l1 is set=20, reg_alpha=0.0 will be ignored. Current value: lambda_l1=20
# [1]	valid_0's binary_logloss: 0.688705
# Training until validation scores don't improve for 50 rounds
# [2]	valid_0's binary_logloss: 0.684221
# [3]	valid_0's binary_logloss: 0.680847
# [4]	valid_0's binary_logloss: 0.677458
# [5]	valid_0's binary_logloss: 0.67507
# [6]	valid_0's binary_logloss: 0.672027
# [7]	valid_0's binary_logloss: 0.67011
# [8]	valid_0's binary_logloss: 0.66797
# [9]	valid_0's binary_logloss: 0.666187
# [10]	valid_0's binary_logloss: 0.664725
# [11]	valid_0's binary_logloss: 0.663607
# [12]	valid_0's binary_logloss: 0.661529
# [13]	valid_0's binary_logloss: 0.659773
# [14]	valid_0's binary_logloss: 0.658505
# [15]	valid_0's binary_logloss: 0.656996
# [16]	valid_0's binary_logloss: 0.655914
# [17]	valid_0's binary_logloss: 0.654017
# [18]	valid_0's binary_logloss: 0.653042
# [19]	valid_0's binary_logloss: 0.65195
# [20]	valid_0's binary_logloss: 0.65012
# [21]	valid_0's binary_logloss: 0.649071
# [22]	valid_0's binary_logloss: 0.648174
# [23]	valid_0's binary_logloss: 0.646869
# [24]	valid_0's binary_logloss: 0.645734
# [25]	valid_0's binary_logloss: 0.644272
# [26]	valid_0's binary_logloss: 0.643192
# [27]	valid_0's binary_logloss: 0.641488
# [28]	valid_0's binary_logloss: 0.640107
# [29]	valid_0's binary_logloss: 0.638995
# [30]	valid_0's binary_logloss: 0.638647
# [31]	valid_0's binary_logloss: 0.637574
# [32]	valid_0's binary_logloss: 0.636298
# [33]	valid_0's binary_logloss: 0.635343
# [34]	valid_0's binary_logloss: 0.634009
# [35]	valid_0's binary_logloss: 0.633401
# [36]	valid_0's binary_logloss: 0.632491
# [37]	valid_0's binary_logloss: 0.631088
# [38]	valid_0's binary_logloss: 0.63047
# [39]	valid_0's binary_logloss: 0.629782
# [40]	valid_0's binary_logloss: 0.62944
# [41]	valid_0's binary_logloss: 0.628591
# [42]	valid_0's binary_logloss: 0.627899
# [43]	valid_0's binary_logloss: 0.626378
# [44]	valid_0's binary_logloss: 0.625633
# [45]	valid_0's binary_logloss: 0.624484
# [46]	valid_0's binary_logloss: 0.623728
# [47]	valid_0's binary_logloss: 0.622655
# [48]	valid_0's binary_logloss: 0.622647
# [49]	valid_0's binary_logloss: 0.622097
# [50]	valid_0's binary_logloss: 0.621536
# [51]	valid_0's binary_logloss: 0.62136
# [52]	valid_0's binary_logloss: 0.621272
# [53]	valid_0's binary_logloss: 0.620325
# [54]	valid_0's binary_logloss: 0.619789
# [55]	valid_0's binary_logloss: 0.618234
# [56]	valid_0's binary_logloss: 0.618068
# [57]	valid_0's binary_logloss: 0.617273
# [58]	valid_0's binary_logloss: 0.616643
# [59]	valid_0's binary_logloss: 0.616559
# [60]	valid_0's binary_logloss: 0.61548
# [61]	valid_0's binary_logloss: 0.615401
# [62]	valid_0's binary_logloss: 0.615104
# [63]	valid_0's binary_logloss: 0.613964
# [64]	valid_0's binary_logloss: 0.613154
# [65]	valid_0's binary_logloss: 0.613053
# [66]	valid_0's binary_logloss: 0.612982
# [67]	valid_0's binary_logloss: 0.612328
# [68]	valid_0's binary_logloss: 0.611633
# [69]	valid_0's binary_logloss: 0.61096
# [70]	valid_0's binary_logloss: 0.610504
# [71]	valid_0's binary_logloss: 0.610346
# [72]	valid_0's binary_logloss: 0.609176
# [73]	valid_0's binary_logloss: 0.608791
# [74]	valid_0's binary_logloss: 0.608012
# [75]	valid_0's binary_logloss: 0.607739
# [76]	valid_0's binary_logloss: 0.607095
# [77]	valid_0's binary_logloss: 0.606812
# [78]	valid_0's binary_logloss: 0.606181
# [79]	valid_0's binary_logloss: 0.605788
# [80]	valid_0's binary_logloss: 0.605434
# [81]	valid_0's binary_logloss: 0.605373
# [82]	valid_0's binary_logloss: 0.604445
# [83]	valid_0's binary_logloss: 0.604351
# [84]	valid_0's binary_logloss: 0.603539
# [85]	valid_0's binary_logloss: 0.603101
# [86]	valid_0's binary_logloss: 0.603142
# [87]	valid_0's binary_logloss: 0.602678
# [88]	valid_0's binary_logloss: 0.602692
# [89]	valid_0's binary_logloss: 0.602286
# [90]	valid_0's binary_logloss: 0.601931
# [91]	valid_0's binary_logloss: 0.601678
# [92]	valid_0's binary_logloss: 0.601316
# [93]	valid_0's binary_logloss: 0.601125
# [94]	valid_0's binary_logloss: 0.600764
# [95]	valid_0's binary_logloss: 0.600355
# [96]	valid_0's binary_logloss: 0.599809
# [97]	valid_0's binary_logloss: 0.599344
# [98]	valid_0's binary_logloss: 0.599035
# [99]	valid_0's binary_logloss: 0.598637
# [100]	valid_0's binary_logloss: 0.59841
# [101]	valid_0's binary_logloss: 0.597965
# [102]	valid_0's binary_logloss: 0.597899
# [103]	valid_0's binary_logloss: 0.597252
# [104]	valid_0's binary_logloss: 0.597019
# [105]	valid_0's binary_logloss: 0.596328
# [106]	valid_0's binary_logloss: 0.595804
# [107]	valid_0's binary_logloss: 0.59573
# [108]	valid_0's binary_logloss: 0.595621
# [109]	valid_0's binary_logloss: 0.595386
# [110]	valid_0's binary_logloss: 0.595136
# [111]	valid_0's binary_logloss: 0.595228
# [112]	valid_0's binary_logloss: 0.594943
# [113]	valid_0's binary_logloss: 0.59469
# [114]	valid_0's binary_logloss: 0.594437
# [115]	valid_0's binary_logloss: 0.594048
# [116]	valid_0's binary_logloss: 0.594143
# [117]	valid_0's binary_logloss: 0.594062
# [118]	valid_0's binary_logloss: 0.593553
# [119]	valid_0's binary_logloss: 0.592981
# [120]	valid_0's binary_logloss: 0.593035
# [121]	valid_0's binary_logloss: 0.593017
# [122]	valid_0's binary_logloss: 0.592635
# [123]	valid_0's binary_logloss: 0.59257
# [124]	valid_0's binary_logloss: 0.592502
# [125]	valid_0's binary_logloss: 0.592323
# [126]	valid_0's binary_logloss: 0.592151
# [127]	valid_0's binary_logloss: 0.591922
# [128]	valid_0's binary_logloss: 0.591851
# [129]	valid_0's binary_logloss: 0.591101
# [130]	valid_0's binary_logloss: 0.59051
# [131]	valid_0's binary_logloss: 0.590287
# [132]	valid_0's binary_logloss: 0.590281
# [133]	valid_0's binary_logloss: 0.590676
# [134]	valid_0's binary_logloss: 0.590059
# [135]	valid_0's binary_logloss: 0.590055
# [136]	valid_0's binary_logloss: 0.58967
# [137]	valid_0's binary_logloss: 0.589665
# [138]	valid_0's binary_logloss: 0.589611
# [139]	valid_0's binary_logloss: 0.589522
# [140]	valid_0's binary_logloss: 0.589275
# [141]	valid_0's binary_logloss: 0.588526
# [142]	valid_0's binary_logloss: 0.588609
# [143]	valid_0's binary_logloss: 0.588132
# [144]	valid_0's binary_logloss: 0.58761
# [145]	valid_0's binary_logloss: 0.587555
# [146]	valid_0's binary_logloss: 0.587168
# [147]	valid_0's binary_logloss: 0.586742
# [148]	valid_0's binary_logloss: 0.586981
# [149]	valid_0's binary_logloss: 0.587174
# [150]	valid_0's binary_logloss: 0.587171
# [151]	valid_0's binary_logloss: 0.587202
# [152]	valid_0's binary_logloss: 0.58693
# [153]	valid_0's binary_logloss: 0.587154
# [154]	valid_0's binary_logloss: 0.586746
# [155]	valid_0's binary_logloss: 0.586557
# [156]	valid_0's binary_logloss: 0.586521
# [157]	valid_0's binary_logloss: 0.58635
# [158]	valid_0's binary_logloss: 0.586113
# [159]	valid_0's binary_logloss: 0.586085
# [160]	valid_0's binary_logloss: 0.586167
# [161]	valid_0's binary_logloss: 0.586159
# [162]	valid_0's binary_logloss: 0.586172
# [163]	valid_0's binary_logloss: 0.585834
# [164]	valid_0's binary_logloss: 0.585754
# [165]	valid_0's binary_logloss: 0.58552
# [166]	valid_0's binary_logloss: 0.585634
# [167]	valid_0's binary_logloss: 0.585485
# [168]	valid_0's binary_logloss: 0.585484
# [169]	valid_0's binary_logloss: 0.585381
# [170]	valid_0's binary_logloss: 0.585345
# [171]	valid_0's binary_logloss: 0.585031
# [172]	valid_0's binary_logloss: 0.585212
# [173]	valid_0's binary_logloss: 0.585078
# [174]	valid_0's binary_logloss: 0.58505
# [175]	valid_0's binary_logloss: 0.585455
# [176]	valid_0's binary_logloss: 0.585272
# [177]	valid_0's binary_logloss: 0.584828
# [178]	valid_0's binary_logloss: 0.584738
# [179]	valid_0's binary_logloss: 0.584701
# [180]	valid_0's binary_logloss: 0.584632
# [181]	valid_0's binary_logloss: 0.584583
# [182]	valid_0's binary_logloss: 0.584371
# [183]	valid_0's binary_logloss: 0.584371
# [184]	valid_0's binary_logloss: 0.584371
# [185]	valid_0's binary_logloss: 0.584371
# [186]	valid_0's binary_logloss: 0.584371
# [187]	valid_0's binary_logloss: 0.584371
# [188]	valid_0's binary_logloss: 0.584371
# [189]	valid_0's binary_logloss: 0.584371
# [190]	valid_0's binary_logloss: 0.584371
# [191]	valid_0's binary_logloss: 0.584371
# [192]	valid_0's binary_logloss: 0.584371
# [193]	valid_0's binary_logloss: 0.584371
# [194]	valid_0's binary_logloss: 0.584371
# [195]	valid_0's binary_logloss: 0.584371
# [196]	valid_0's binary_logloss: 0.584371
# [197]	valid_0's binary_logloss: 0.584371
# [198]	valid_0's binary_logloss: 0.584371
# [199]	valid_0's binary_logloss: 0.584371
# [200]	valid_0's binary_logloss: 0.584371
# Did not meet early stopping. Best iteration is:
# [182]	valid_0's binary_logloss: 0.584371
# [LightGBM] [Warning] min_gain_to_split is set=0.3386864392910829, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=0.3386864392910829
# [LightGBM] [Warning] feature_fraction is set=0.8487835385101288, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8487835385101288
# [LightGBM] [Warning] bagging_fraction is set=0.7634888813192431, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7634888813192431
# [LightGBM] [Warning] lambda_l2 is set=39, reg_lambda=0.0 will be ignored. Current value: lambda_l2=39
# [LightGBM] [Warning] lambda_l1 is set=20, reg_alpha=0.0 will be ignored. Current value: lambda_l1=20
# [1]	valid_0's binary_logloss: 0.688829
# Training until validation scores don't improve for 50 rounds
# [2]	valid_0's binary_logloss: 0.685108
# [3]	valid_0's binary_logloss: 0.682233
# [4]	valid_0's binary_logloss: 0.67972
# [5]	valid_0's binary_logloss: 0.676993
# [6]	valid_0's binary_logloss: 0.674263
# [7]	valid_0's binary_logloss: 0.671128
# [8]	valid_0's binary_logloss: 0.669377
# [9]	valid_0's binary_logloss: 0.666666
# [10]	valid_0's binary_logloss: 0.66571
# [11]	valid_0's binary_logloss: 0.663621
# [12]	valid_0's binary_logloss: 0.66209
# [13]	valid_0's binary_logloss: 0.660106
# [14]	valid_0's binary_logloss: 0.659063
# [15]	valid_0's binary_logloss: 0.657227
# [16]	valid_0's binary_logloss: 0.655554
# [17]	valid_0's binary_logloss: 0.654123
# [18]	valid_0's binary_logloss: 0.651825
# [19]	valid_0's binary_logloss: 0.650073
# [20]	valid_0's binary_logloss: 0.648579
# [21]	valid_0's binary_logloss: 0.647329
# [22]	valid_0's binary_logloss: 0.646532
# [23]	valid_0's binary_logloss: 0.645038
# [24]	valid_0's binary_logloss: 0.643984
# [25]	valid_0's binary_logloss: 0.643225
# [26]	valid_0's binary_logloss: 0.642127
# [27]	valid_0's binary_logloss: 0.641391
# [28]	valid_0's binary_logloss: 0.640245
# [29]	valid_0's binary_logloss: 0.638587
# [30]	valid_0's binary_logloss: 0.638097
# [31]	valid_0's binary_logloss: 0.637292
# [32]	valid_0's binary_logloss: 0.636628
# [33]	valid_0's binary_logloss: 0.635609
# [34]	valid_0's binary_logloss: 0.634541
# [35]	valid_0's binary_logloss: 0.633771
# [36]	valid_0's binary_logloss: 0.632936
# [37]	valid_0's binary_logloss: 0.631496
# [38]	valid_0's binary_logloss: 0.630392
# [39]	valid_0's binary_logloss: 0.629637
# [40]	valid_0's binary_logloss: 0.628566
# [41]	valid_0's binary_logloss: 0.627716
# [42]	valid_0's binary_logloss: 0.627156
# [43]	valid_0's binary_logloss: 0.626845
# [44]	valid_0's binary_logloss: 0.625583
# [45]	valid_0's binary_logloss: 0.624605
# [46]	valid_0's binary_logloss: 0.623652
# [47]	valid_0's binary_logloss: 0.622441
# [48]	valid_0's binary_logloss: 0.62156
# [49]	valid_0's binary_logloss: 0.621094
# [50]	valid_0's binary_logloss: 0.621043
# [51]	valid_0's binary_logloss: 0.621445
# [52]	valid_0's binary_logloss: 0.620033
# [53]	valid_0's binary_logloss: 0.619328
# [54]	valid_0's binary_logloss: 0.61887
# [55]	valid_0's binary_logloss: 0.618113
# [56]	valid_0's binary_logloss: 0.617396
# [57]	valid_0's binary_logloss: 0.616902
# [58]	valid_0's binary_logloss: 0.616674
# [59]	valid_0's binary_logloss: 0.616358
# [60]	valid_0's binary_logloss: 0.616109
# [61]	valid_0's binary_logloss: 0.615446
# [62]	valid_0's binary_logloss: 0.6151
# [63]	valid_0's binary_logloss: 0.614871
# [64]	valid_0's binary_logloss: 0.614128
# [65]	valid_0's binary_logloss: 0.613103
# [66]	valid_0's binary_logloss: 0.612756
# [67]	valid_0's binary_logloss: 0.612118
# [68]	valid_0's binary_logloss: 0.611698
# [69]	valid_0's binary_logloss: 0.611488
# [70]	valid_0's binary_logloss: 0.610801
# [71]	valid_0's binary_logloss: 0.610063
# [72]	valid_0's binary_logloss: 0.609258
# [73]	valid_0's binary_logloss: 0.60903
# [74]	valid_0's binary_logloss: 0.608324
# [75]	valid_0's binary_logloss: 0.607873
# [76]	valid_0's binary_logloss: 0.60744
# [77]	valid_0's binary_logloss: 0.607063
# [78]	valid_0's binary_logloss: 0.606732
# [79]	valid_0's binary_logloss: 0.606341
# [80]	valid_0's binary_logloss: 0.606374
# [81]	valid_0's binary_logloss: 0.605673
# [82]	valid_0's binary_logloss: 0.605651
# [83]	valid_0's binary_logloss: 0.60534
# [84]	valid_0's binary_logloss: 0.605261
# [85]	valid_0's binary_logloss: 0.605007
# [86]	valid_0's binary_logloss: 0.604713
# [87]	valid_0's binary_logloss: 0.604672
# [88]	valid_0's binary_logloss: 0.604597
# [89]	valid_0's binary_logloss: 0.604486
# [90]	valid_0's binary_logloss: 0.604092
# [91]	valid_0's binary_logloss: 0.603853
# [92]	valid_0's binary_logloss: 0.603497
# [93]	valid_0's binary_logloss: 0.60277
# [94]	valid_0's binary_logloss: 0.602783
# [95]	valid_0's binary_logloss: 0.602059
# [96]	valid_0's binary_logloss: 0.601556
# [97]	valid_0's binary_logloss: 0.601098
# [98]	valid_0's binary_logloss: 0.601204
# [99]	valid_0's binary_logloss: 0.600447
# [100]	valid_0's binary_logloss: 0.600111
# [101]	valid_0's binary_logloss: 0.599457
# [102]	valid_0's binary_logloss: 0.598239
# [103]	valid_0's binary_logloss: 0.598295
# [104]	valid_0's binary_logloss: 0.598031
# [105]	valid_0's binary_logloss: 0.598145
# [106]	valid_0's binary_logloss: 0.597537
# [107]	valid_0's binary_logloss: 0.597285
# [108]	valid_0's binary_logloss: 0.597046
# [109]	valid_0's binary_logloss: 0.596413
# [110]	valid_0's binary_logloss: 0.596767
# [111]	valid_0's binary_logloss: 0.596564
# [112]	valid_0's binary_logloss: 0.596375
# [113]	valid_0's binary_logloss: 0.595668
# [114]	valid_0's binary_logloss: 0.595541
# [115]	valid_0's binary_logloss: 0.594669
# [116]	valid_0's binary_logloss: 0.594472
# [117]	valid_0's binary_logloss: 0.594628
# [118]	valid_0's binary_logloss: 0.594306
# [119]	valid_0's binary_logloss: 0.593761
# [120]	valid_0's binary_logloss: 0.594066
# [121]	valid_0's binary_logloss: 0.594005
# [122]	valid_0's binary_logloss: 0.594015
# [123]	valid_0's binary_logloss: 0.593567
# [124]	valid_0's binary_logloss: 0.593267
# [125]	valid_0's binary_logloss: 0.593408
# [126]	valid_0's binary_logloss: 0.593586
# [127]	valid_0's binary_logloss: 0.593385
# [128]	valid_0's binary_logloss: 0.593009
# [129]	valid_0's binary_logloss: 0.592731
# [130]	valid_0's binary_logloss: 0.592444
# [131]	valid_0's binary_logloss: 0.592221
# [132]	valid_0's binary_logloss: 0.59254
# [133]	valid_0's binary_logloss: 0.592378
# [134]	valid_0's binary_logloss: 0.591689
# [135]	valid_0's binary_logloss: 0.591261
# [136]	valid_0's binary_logloss: 0.591112
# [137]	valid_0's binary_logloss: 0.591447
# [138]	valid_0's binary_logloss: 0.591359
# [139]	valid_0's binary_logloss: 0.591066
# [140]	valid_0's binary_logloss: 0.59112
# [141]	valid_0's binary_logloss: 0.591505
# [142]	valid_0's binary_logloss: 0.590955
# [143]	valid_0's binary_logloss: 0.590336
# [144]	valid_0's binary_logloss: 0.590401
# [145]	valid_0's binary_logloss: 0.590058
# [146]	valid_0's binary_logloss: 0.589865
# [147]	valid_0's binary_logloss: 0.589724
# [148]	valid_0's binary_logloss: 0.589367
# [149]	valid_0's binary_logloss: 0.589271
# [150]	valid_0's binary_logloss: 0.58899
# [151]	valid_0's binary_logloss: 0.589245
# [152]	valid_0's binary_logloss: 0.589152
# [153]	valid_0's binary_logloss: 0.589158
# [154]	valid_0's binary_logloss: 0.58883
# [155]	valid_0's binary_logloss: 0.588918
# [156]	valid_0's binary_logloss: 0.588929
# [157]	valid_0's binary_logloss: 0.588584
# [158]	valid_0's binary_logloss: 0.588691
# [159]	valid_0's binary_logloss: 0.588501
# [160]	valid_0's binary_logloss: 0.58825
# [161]	valid_0's binary_logloss: 0.588163
# [162]	valid_0's binary_logloss: 0.588262
# [163]	valid_0's binary_logloss: 0.588557
# [164]	valid_0's binary_logloss: 0.588567
# [165]	valid_0's binary_logloss: 0.588242
# [166]	valid_0's binary_logloss: 0.588244
# [167]	valid_0's binary_logloss: 0.587964
# [168]	valid_0's binary_logloss: 0.588112
# [169]	valid_0's binary_logloss: 0.587944
# [170]	valid_0's binary_logloss: 0.587607
# [171]	valid_0's binary_logloss: 0.587521
# [172]	valid_0's binary_logloss: 0.587605
# [173]	valid_0's binary_logloss: 0.58761
# [174]	valid_0's binary_logloss: 0.587601
# [175]	valid_0's binary_logloss: 0.587285
# [176]	valid_0's binary_logloss: 0.587309
# [177]	valid_0's binary_logloss: 0.587264
# [178]	valid_0's binary_logloss: 0.587264
# [179]	valid_0's binary_logloss: 0.587264
# [180]	valid_0's binary_logloss: 0.587264
# [181]	valid_0's binary_logloss: 0.587264
# [182]	valid_0's binary_logloss: 0.587264
# [183]	valid_0's binary_logloss: 0.587264
# [184]	valid_0's binary_logloss: 0.587264
# [185]	valid_0's binary_logloss: 0.587264
# [186]	valid_0's binary_logloss: 0.587264
# [187]	valid_0's binary_logloss: 0.587264
# [188]	valid_0's binary_logloss: 0.587264
# [189]	valid_0's binary_logloss: 0.587264
# [190]	valid_0's binary_logloss: 0.587264
# [191]	valid_0's binary_logloss: 0.587264
# [192]	valid_0's binary_logloss: 0.587264
# [193]	valid_0's binary_logloss: 0.587264
# [194]	valid_0's binary_logloss: 0.587264
# [195]	valid_0's binary_logloss: 0.587264
# [196]	valid_0's binary_logloss: 0.587264
# [197]	valid_0's binary_logloss: 0.587264
# [198]	valid_0's binary_logloss: 0.587264
# [199]	valid_0's binary_logloss: 0.587264
# [200]	valid_0's binary_logloss: 0.587264
# Did not meet early stopping. Best iteration is:
# [177]	valid_0's binary_logloss: 0.587264
# [LightGBM] [Warning] min_gain_to_split is set=0.3386864392910829, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=0.3386864392910829
# [LightGBM] [Warning] feature_fraction is set=0.8487835385101288, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8487835385101288
# [LightGBM] [Warning] bagging_fraction is set=0.7634888813192431, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7634888813192431
# [LightGBM] [Warning] lambda_l2 is set=39, reg_lambda=0.0 will be ignored. Current value: lambda_l2=39
# [LightGBM] [Warning] lambda_l1 is set=20, reg_alpha=0.0 will be ignored. Current value: lambda_l1=20
# [1]	valid_0's binary_logloss: 0.688829
# Training until validation scores don't improve for 50 rounds
# [2]	valid_0's binary_logloss: 0.684558
# [3]	valid_0's binary_logloss: 0.680764
# [4]	valid_0's binary_logloss: 0.676713
# [5]	valid_0's binary_logloss: 0.673363
# [6]	valid_0's binary_logloss: 0.670869
# [7]	valid_0's binary_logloss: 0.667987
# [8]	valid_0's binary_logloss: 0.666987
# [9]	valid_0's binary_logloss: 0.664486
# [10]	valid_0's binary_logloss: 0.662802
# [11]	valid_0's binary_logloss: 0.66212
# [12]	valid_0's binary_logloss: 0.660117
# [13]	valid_0's binary_logloss: 0.658615
# [14]	valid_0's binary_logloss: 0.657719
# [15]	valid_0's binary_logloss: 0.656057
# [16]	valid_0's binary_logloss: 0.654543
# [17]	valid_0's binary_logloss: 0.652727
# [18]	valid_0's binary_logloss: 0.652303
# [19]	valid_0's binary_logloss: 0.650997
# [20]	valid_0's binary_logloss: 0.649869
# [21]	valid_0's binary_logloss: 0.64881
# [22]	valid_0's binary_logloss: 0.647503
# [23]	valid_0's binary_logloss: 0.645818
# [24]	valid_0's binary_logloss: 0.644735
# [25]	valid_0's binary_logloss: 0.64391
# [26]	valid_0's binary_logloss: 0.643097
# [27]	valid_0's binary_logloss: 0.641396
# [28]	valid_0's binary_logloss: 0.640457
# [29]	valid_0's binary_logloss: 0.640081
# [30]	valid_0's binary_logloss: 0.638985
# [31]	valid_0's binary_logloss: 0.637406
# [32]	valid_0's binary_logloss: 0.636504
# [33]	valid_0's binary_logloss: 0.635041
# [34]	valid_0's binary_logloss: 0.634404
# [35]	valid_0's binary_logloss: 0.633643
# [36]	valid_0's binary_logloss: 0.63282
# [37]	valid_0's binary_logloss: 0.631961
# [38]	valid_0's binary_logloss: 0.630438
# [39]	valid_0's binary_logloss: 0.629697
# [40]	valid_0's binary_logloss: 0.628868
# [41]	valid_0's binary_logloss: 0.628059
# [42]	valid_0's binary_logloss: 0.62748
# [43]	valid_0's binary_logloss: 0.626028
# [44]	valid_0's binary_logloss: 0.625431
# [45]	valid_0's binary_logloss: 0.625022
# [46]	valid_0's binary_logloss: 0.624719
# [47]	valid_0's binary_logloss: 0.624527
# [48]	valid_0's binary_logloss: 0.622854
# [49]	valid_0's binary_logloss: 0.621415
# [50]	valid_0's binary_logloss: 0.620583
# [51]	valid_0's binary_logloss: 0.61978
# [52]	valid_0's binary_logloss: 0.619114
# [53]	valid_0's binary_logloss: 0.618909
# [54]	valid_0's binary_logloss: 0.618572
# [55]	valid_0's binary_logloss: 0.618061
# [56]	valid_0's binary_logloss: 0.617644
# [57]	valid_0's binary_logloss: 0.617175
# [58]	valid_0's binary_logloss: 0.616992
# [59]	valid_0's binary_logloss: 0.616235
# [60]	valid_0's binary_logloss: 0.616108
# [61]	valid_0's binary_logloss: 0.615427
# [62]	valid_0's binary_logloss: 0.614624
# [63]	valid_0's binary_logloss: 0.613469
# [64]	valid_0's binary_logloss: 0.612927
# [65]	valid_0's binary_logloss: 0.612761
# [66]	valid_0's binary_logloss: 0.612653
# [67]	valid_0's binary_logloss: 0.611622
# [68]	valid_0's binary_logloss: 0.611402
# [69]	valid_0's binary_logloss: 0.611231
# [70]	valid_0's binary_logloss: 0.610395
# [71]	valid_0's binary_logloss: 0.609787
# [72]	valid_0's binary_logloss: 0.609388
# [73]	valid_0's binary_logloss: 0.60897
# [74]	valid_0's binary_logloss: 0.608587
# [75]	valid_0's binary_logloss: 0.607805
# [76]	valid_0's binary_logloss: 0.607749
# [77]	valid_0's binary_logloss: 0.607338
# [78]	valid_0's binary_logloss: 0.60657
# [79]	valid_0's binary_logloss: 0.605545
# [80]	valid_0's binary_logloss: 0.605162
# [81]	valid_0's binary_logloss: 0.605409
# [82]	valid_0's binary_logloss: 0.605099
# [83]	valid_0's binary_logloss: 0.604583
# [84]	valid_0's binary_logloss: 0.604186
# [85]	valid_0's binary_logloss: 0.603366
# [86]	valid_0's binary_logloss: 0.602935
# [87]	valid_0's binary_logloss: 0.6033
# [88]	valid_0's binary_logloss: 0.602944
# [89]	valid_0's binary_logloss: 0.602375
# [90]	valid_0's binary_logloss: 0.602154
# [91]	valid_0's binary_logloss: 0.601834
# [92]	valid_0's binary_logloss: 0.601481
# [93]	valid_0's binary_logloss: 0.600856
# [94]	valid_0's binary_logloss: 0.600665
# [95]	valid_0's binary_logloss: 0.600526
# [96]	valid_0's binary_logloss: 0.600318
# [97]	valid_0's binary_logloss: 0.600255
# [98]	valid_0's binary_logloss: 0.5998
# [99]	valid_0's binary_logloss: 0.599453
# [100]	valid_0's binary_logloss: 0.598884
# [101]	valid_0's binary_logloss: 0.598682
# [102]	valid_0's binary_logloss: 0.597954
# [103]	valid_0's binary_logloss: 0.597728
# [104]	valid_0's binary_logloss: 0.597189
# [105]	valid_0's binary_logloss: 0.597263
# [106]	valid_0's binary_logloss: 0.596577
# [107]	valid_0's binary_logloss: 0.596311
# [108]	valid_0's binary_logloss: 0.595938
# [109]	valid_0's binary_logloss: 0.595866
# [110]	valid_0's binary_logloss: 0.59547
# [111]	valid_0's binary_logloss: 0.59518
# [112]	valid_0's binary_logloss: 0.595096
# [113]	valid_0's binary_logloss: 0.595228
# [114]	valid_0's binary_logloss: 0.595071
# [115]	valid_0's binary_logloss: 0.594824
# [116]	valid_0's binary_logloss: 0.594513
# [117]	valid_0's binary_logloss: 0.593754
# [118]	valid_0's binary_logloss: 0.59351
# [119]	valid_0's binary_logloss: 0.593338
# [120]	valid_0's binary_logloss: 0.592897
# [121]	valid_0's binary_logloss: 0.592847
# [122]	valid_0's binary_logloss: 0.592566
# [123]	valid_0's binary_logloss: 0.592814
# [124]	valid_0's binary_logloss: 0.592776
# [125]	valid_0's binary_logloss: 0.592625
# [126]	valid_0's binary_logloss: 0.592385
# [127]	valid_0's binary_logloss: 0.591886
# [128]	valid_0's binary_logloss: 0.591671
# [129]	valid_0's binary_logloss: 0.590932
# [130]	valid_0's binary_logloss: 0.590762
# [131]	valid_0's binary_logloss: 0.590819
# [132]	valid_0's binary_logloss: 0.590482
# [133]	valid_0's binary_logloss: 0.590585
# [134]	valid_0's binary_logloss: 0.590317
# [135]	valid_0's binary_logloss: 0.590384
# [136]	valid_0's binary_logloss: 0.589999
# [137]	valid_0's binary_logloss: 0.590039
# [138]	valid_0's binary_logloss: 0.589695
# [139]	valid_0's binary_logloss: 0.589705
# [140]	valid_0's binary_logloss: 0.589328
# [141]	valid_0's binary_logloss: 0.589205
# [142]	valid_0's binary_logloss: 0.588806
# [143]	valid_0's binary_logloss: 0.588797
# [144]	valid_0's binary_logloss: 0.588422
# [145]	valid_0's binary_logloss: 0.588361
# [146]	valid_0's binary_logloss: 0.588194
# [147]	valid_0's binary_logloss: 0.587952
# [148]	valid_0's binary_logloss: 0.588144
# [149]	valid_0's binary_logloss: 0.587948
# [150]	valid_0's binary_logloss: 0.587567
# [151]	valid_0's binary_logloss: 0.587466
# [152]	valid_0's binary_logloss: 0.587273
# [153]	valid_0's binary_logloss: 0.587418
# [154]	valid_0's binary_logloss: 0.587401
# [155]	valid_0's binary_logloss: 0.58734
# [156]	valid_0's binary_logloss: 0.587591
# [157]	valid_0's binary_logloss: 0.587448
# [158]	valid_0's binary_logloss: 0.58723
# [159]	valid_0's binary_logloss: 0.587256
# [160]	valid_0's binary_logloss: 0.587372
# [161]	valid_0's binary_logloss: 0.587125
# [162]	valid_0's binary_logloss: 0.587206
# [163]	valid_0's binary_logloss: 0.587015
# [164]	valid_0's binary_logloss: 0.58678
# [165]	valid_0's binary_logloss: 0.58673
# [166]	valid_0's binary_logloss: 0.586723
# [167]	valid_0's binary_logloss: 0.586622
# [168]	valid_0's binary_logloss: 0.586658
# [169]	valid_0's binary_logloss: 0.586561
# [170]	valid_0's binary_logloss: 0.586587
# [171]	valid_0's binary_logloss: 0.586467
# [172]	valid_0's binary_logloss: 0.586467
# [173]	valid_0's binary_logloss: 0.586467
# [174]	valid_0's binary_logloss: 0.586467
# [175]	valid_0's binary_logloss: 0.586467
# [176]	valid_0's binary_logloss: 0.586467
# [177]	valid_0's binary_logloss: 0.586467
# [178]	valid_0's binary_logloss: 0.586467
# [179]	valid_0's binary_logloss: 0.586467
# [180]	valid_0's binary_logloss: 0.586467
# [181]	valid_0's binary_logloss: 0.586467
# [182]	valid_0's binary_logloss: 0.586467
# [183]	valid_0's binary_logloss: 0.586467
# [184]	valid_0's binary_logloss: 0.586467
# [185]	valid_0's binary_logloss: 0.586467
# [186]	valid_0's binary_logloss: 0.586467
# [187]	valid_0's binary_logloss: 0.586467
# [188]	valid_0's binary_logloss: 0.586467
# [189]	valid_0's binary_logloss: 0.586467
# [190]	valid_0's binary_logloss: 0.586467
# [191]	valid_0's binary_logloss: 0.586467
# [192]	valid_0's binary_logloss: 0.586467
# [193]	valid_0's binary_logloss: 0.586467
# [194]	valid_0's binary_logloss: 0.586467
# [195]	valid_0's binary_logloss: 0.586467
# [196]	valid_0's binary_logloss: 0.586467
# [197]	valid_0's binary_logloss: 0.586467
# [198]	valid_0's binary_logloss: 0.586467
# [199]	valid_0's binary_logloss: 0.586467
# [200]	valid_0's binary_logloss: 0.586467
# Did not meet early stopping. Best iteration is:
# [171]	valid_0's binary_logloss: 0.586467
# [LightGBM] [Warning] min_gain_to_split is set=0.3386864392910829, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=0.3386864392910829
# [LightGBM] [Warning] feature_fraction is set=0.8487835385101288, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8487835385101288
# [LightGBM] [Warning] bagging_fraction is set=0.7634888813192431, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7634888813192431
# [LightGBM] [Warning] lambda_l2 is set=39, reg_lambda=0.0 will be ignored. Current value: lambda_l2=39
# [LightGBM] [Warning] lambda_l1 is set=20, reg_alpha=0.0 will be ignored. Current value: lambda_l1=20
# [1]	valid_0's binary_logloss: 0.688873
# Training until validation scores don't improve for 50 rounds
# [2]	valid_0's binary_logloss: 0.684756
# [3]	valid_0's binary_logloss: 0.68181
# [4]	valid_0's binary_logloss: 0.678025
# [5]	valid_0's binary_logloss: 0.674573
# [6]	valid_0's binary_logloss: 0.671519
# [7]	valid_0's binary_logloss: 0.669457
# [8]	valid_0's binary_logloss: 0.667587
# [9]	valid_0's binary_logloss: 0.665054
# [10]	valid_0's binary_logloss: 0.66223
# [11]	valid_0's binary_logloss: 0.661214
# [12]	valid_0's binary_logloss: 0.659258
# [13]	valid_0's binary_logloss: 0.657975
# [14]	valid_0's binary_logloss: 0.656755
# [15]	valid_0's binary_logloss: 0.654941
# [16]	valid_0's binary_logloss: 0.653297
# [17]	valid_0's binary_logloss: 0.651195
# [18]	valid_0's binary_logloss: 0.649033
# [19]	valid_0's binary_logloss: 0.647468
# [20]	valid_0's binary_logloss: 0.646046
# [21]	valid_0's binary_logloss: 0.645349
# [22]	valid_0's binary_logloss: 0.643877
# [23]	valid_0's binary_logloss: 0.642784
# [24]	valid_0's binary_logloss: 0.642441
# [25]	valid_0's binary_logloss: 0.641512
# [26]	valid_0's binary_logloss: 0.640403
# [27]	valid_0's binary_logloss: 0.638815
# [28]	valid_0's binary_logloss: 0.637817
# [29]	valid_0's binary_logloss: 0.637767
# [30]	valid_0's binary_logloss: 0.636369
# [31]	valid_0's binary_logloss: 0.635457
# [32]	valid_0's binary_logloss: 0.634316
# [33]	valid_0's binary_logloss: 0.63332
# [34]	valid_0's binary_logloss: 0.632502
# [35]	valid_0's binary_logloss: 0.631104
# [36]	valid_0's binary_logloss: 0.6298
# [37]	valid_0's binary_logloss: 0.629464
# [38]	valid_0's binary_logloss: 0.62923
# [39]	valid_0's binary_logloss: 0.628408
# [40]	valid_0's binary_logloss: 0.627657
# [41]	valid_0's binary_logloss: 0.626693
# [42]	valid_0's binary_logloss: 0.625572
# [43]	valid_0's binary_logloss: 0.625125
# [44]	valid_0's binary_logloss: 0.624278
# [45]	valid_0's binary_logloss: 0.623735
# [46]	valid_0's binary_logloss: 0.623327
# [47]	valid_0's binary_logloss: 0.622198
# [48]	valid_0's binary_logloss: 0.621193
# [49]	valid_0's binary_logloss: 0.620585
# [50]	valid_0's binary_logloss: 0.619517
# [51]	valid_0's binary_logloss: 0.61817
# [52]	valid_0's binary_logloss: 0.618154
# [53]	valid_0's binary_logloss: 0.617943
# [54]	valid_0's binary_logloss: 0.616362
# [55]	valid_0's binary_logloss: 0.615854
# [56]	valid_0's binary_logloss: 0.615438
# [57]	valid_0's binary_logloss: 0.614753
# [58]	valid_0's binary_logloss: 0.614272
# [59]	valid_0's binary_logloss: 0.613118
# [60]	valid_0's binary_logloss: 0.612732
# [61]	valid_0's binary_logloss: 0.612087
# [62]	valid_0's binary_logloss: 0.611189
# [63]	valid_0's binary_logloss: 0.610294
# [64]	valid_0's binary_logloss: 0.610289
# [65]	valid_0's binary_logloss: 0.609215
# [66]	valid_0's binary_logloss: 0.608739
# [67]	valid_0's binary_logloss: 0.608687
# [68]	valid_0's binary_logloss: 0.608248
# [69]	valid_0's binary_logloss: 0.608041
# [70]	valid_0's binary_logloss: 0.608118
# [71]	valid_0's binary_logloss: 0.607204
# [72]	valid_0's binary_logloss: 0.606294
# [73]	valid_0's binary_logloss: 0.606436
# [74]	valid_0's binary_logloss: 0.605977
# [75]	valid_0's binary_logloss: 0.604588
# [76]	valid_0's binary_logloss: 0.604533
# [77]	valid_0's binary_logloss: 0.604321
# [78]	valid_0's binary_logloss: 0.604225
# [79]	valid_0's binary_logloss: 0.603772
# [80]	valid_0's binary_logloss: 0.602919
# [81]	valid_0's binary_logloss: 0.602479
# [82]	valid_0's binary_logloss: 0.602568
# [83]	valid_0's binary_logloss: 0.602545
# [84]	valid_0's binary_logloss: 0.602238
# [85]	valid_0's binary_logloss: 0.601717
# [86]	valid_0's binary_logloss: 0.601182
# [87]	valid_0's binary_logloss: 0.600468
# [88]	valid_0's binary_logloss: 0.599892
# [89]	valid_0's binary_logloss: 0.599452
# [90]	valid_0's binary_logloss: 0.59883
# [91]	valid_0's binary_logloss: 0.598473
# [92]	valid_0's binary_logloss: 0.59834
# [93]	valid_0's binary_logloss: 0.597885
# [94]	valid_0's binary_logloss: 0.597851
# [95]	valid_0's binary_logloss: 0.597278
# [96]	valid_0's binary_logloss: 0.596962
# [97]	valid_0's binary_logloss: 0.596077
# [98]	valid_0's binary_logloss: 0.595754
# [99]	valid_0's binary_logloss: 0.596024
# [100]	valid_0's binary_logloss: 0.595945
# [101]	valid_0's binary_logloss: 0.595443
# [102]	valid_0's binary_logloss: 0.595508
# [103]	valid_0's binary_logloss: 0.595059
# [104]	valid_0's binary_logloss: 0.59499
# [105]	valid_0's binary_logloss: 0.59476
# [106]	valid_0's binary_logloss: 0.594639
# [107]	valid_0's binary_logloss: 0.594444
# [108]	valid_0's binary_logloss: 0.59448
# [109]	valid_0's binary_logloss: 0.593763
# [110]	valid_0's binary_logloss: 0.593174
# [111]	valid_0's binary_logloss: 0.592976
# [112]	valid_0's binary_logloss: 0.592924
# [113]	valid_0's binary_logloss: 0.592852
# [114]	valid_0's binary_logloss: 0.592679
# [115]	valid_0's binary_logloss: 0.59221
# [116]	valid_0's binary_logloss: 0.592416
# [117]	valid_0's binary_logloss: 0.59205
# [118]	valid_0's binary_logloss: 0.591591
# [119]	valid_0's binary_logloss: 0.591469
# [120]	valid_0's binary_logloss: 0.590867
# [121]	valid_0's binary_logloss: 0.590616
# [122]	valid_0's binary_logloss: 0.590708
# [123]	valid_0's binary_logloss: 0.590653
# [124]	valid_0's binary_logloss: 0.590324
# [125]	valid_0's binary_logloss: 0.590326
# [126]	valid_0's binary_logloss: 0.590607
# [127]	valid_0's binary_logloss: 0.590339
# [128]	valid_0's binary_logloss: 0.590081
# [129]	valid_0's binary_logloss: 0.589488
# [130]	valid_0's binary_logloss: 0.58916
# [131]	valid_0's binary_logloss: 0.58913
# [132]	valid_0's binary_logloss: 0.588634
# [133]	valid_0's binary_logloss: 0.588009
# [134]	valid_0's binary_logloss: 0.587865
# [135]	valid_0's binary_logloss: 0.588198
# [136]	valid_0's binary_logloss: 0.588116
# [137]	valid_0's binary_logloss: 0.588057
# [138]	valid_0's binary_logloss: 0.587807
# [139]	valid_0's binary_logloss: 0.587648
# [140]	valid_0's binary_logloss: 0.587446
# [141]	valid_0's binary_logloss: 0.587141
# [142]	valid_0's binary_logloss: 0.587067
# [143]	valid_0's binary_logloss: 0.587421
# [144]	valid_0's binary_logloss: 0.587198
# [145]	valid_0's binary_logloss: 0.587279
# [146]	valid_0's binary_logloss: 0.586636
# [147]	valid_0's binary_logloss: 0.586544
# [148]	valid_0's binary_logloss: 0.586621
# [149]	valid_0's binary_logloss: 0.586611
# [150]	valid_0's binary_logloss: 0.586665
# [151]	valid_0's binary_logloss: 0.586713
# [152]	valid_0's binary_logloss: 0.586917
# [153]	valid_0's binary_logloss: 0.586861
# [154]	valid_0's binary_logloss: 0.586665
# [155]	valid_0's binary_logloss: 0.586665
# [156]	valid_0's binary_logloss: 0.586665
# [157]	valid_0's binary_logloss: 0.586665
# [158]	valid_0's binary_logloss: 0.586665
# [159]	valid_0's binary_logloss: 0.586665
# [160]	valid_0's binary_logloss: 0.586665
# [161]	valid_0's binary_logloss: 0.586665
# [162]	valid_0's binary_logloss: 0.586665
# [163]	valid_0's binary_logloss: 0.586665
# [164]	valid_0's binary_logloss: 0.586665
# [165]	valid_0's binary_logloss: 0.586665
# [166]	valid_0's binary_logloss: 0.586665
# [167]	valid_0's binary_logloss: 0.586665
# [168]	valid_0's binary_logloss: 0.586665
# [169]	valid_0's binary_logloss: 0.586665
# [170]	valid_0's binary_logloss: 0.586665
# [171]	valid_0's binary_logloss: 0.586665
# [172]	valid_0's binary_logloss: 0.586665
# [173]	valid_0's binary_logloss: 0.586665
# [174]	valid_0's binary_logloss: 0.586665
# [175]	valid_0's binary_logloss: 0.586665
# [176]	valid_0's binary_logloss: 0.586665
# [177]	valid_0's binary_logloss: 0.586665
# [178]	valid_0's binary_logloss: 0.586665
# [179]	valid_0's binary_logloss: 0.586665
# [180]	valid_0's binary_logloss: 0.586665
# [181]	valid_0's binary_logloss: 0.586665
# [182]	valid_0's binary_logloss: 0.586665
# [183]	valid_0's binary_logloss: 0.586665
# [184]	valid_0's binary_logloss: 0.586665
# [185]	valid_0's binary_logloss: 0.586665
# [186]	valid_0's binary_logloss: 0.586665
# [187]	valid_0's binary_logloss: 0.586665
# [188]	valid_0's binary_logloss: 0.586665
# [189]	valid_0's binary_logloss: 0.586665
# [190]	valid_0's binary_logloss: 0.586665
# [191]	valid_0's binary_logloss: 0.586665
# [192]	valid_0's binary_logloss: 0.586665
# [193]	valid_0's binary_logloss: 0.586665
# [194]	valid_0's binary_logloss: 0.586665
# [195]	valid_0's binary_logloss: 0.586665
# [196]	valid_0's binary_logloss: 0.586665
# [197]	valid_0's binary_logloss: 0.586665
# Early stopping, best iteration is:
# [147]	valid_0's binary_logloss: 0.586544
# [LightGBM] [Warning] min_gain_to_split is set=0.2482221429340636, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=0.2482221429340636
# [LightGBM] [Warning] feature_fraction is set=0.7785156184605516, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7785156184605516
# [LightGBM] [Warning] bagging_fraction is set=0.463874133489399, subsample=1.0 will be ignored. Current value: bagging_fraction=0.463874133489399
# [LightGBM] [Warning] lambda_l2 is set=24, reg_lambda=0.0 will be ignored. Current value: lambda_l2=24
# [LightGBM] [Warning] lambda_l1 is set=17, reg_alpha=0.0 will be ignored. Current value: lambda_l1=17
# [1]	valid_0's binary_logloss: 0.688005
# Training until validation scores don't improve for 50 rounds
# [2]	valid_0's binary_logloss: 0.683234
# [3]	valid_0's binary_logloss: 0.679717
# [4]	valid_0's binary_logloss: 0.675246
# [5]	valid_0's binary_logloss: 0.672509
# [6]	valid_0's binary_logloss: 0.668715
# [7]	valid_0's binary_logloss: 0.665322
# [8]	valid_0's binary_logloss: 0.663423
# [9]	valid_0's binary_logloss: 0.660203
# [10]	valid_0's binary_logloss: 0.658659
# [11]	valid_0's binary_logloss: 0.657011
# [12]	valid_0's binary_logloss: 0.654563
# [13]	valid_0's binary_logloss: 0.652591
# [14]	valid_0's binary_logloss: 0.650388
# [15]	valid_0's binary_logloss: 0.649051
# [16]	valid_0's binary_logloss: 0.64764
# [17]	valid_0's binary_logloss: 0.645742
# [18]	valid_0's binary_logloss: 0.644074
# [19]	valid_0's binary_logloss: 0.642346
# [20]	valid_0's binary_logloss: 0.641013
# [21]	valid_0's binary_logloss: 0.639834
# [22]	valid_0's binary_logloss: 0.639095
# [23]	valid_0's binary_logloss: 0.637076
# [24]	valid_0's binary_logloss: 0.635487
# [25]	valid_0's binary_logloss: 0.634152
# [26]	valid_0's binary_logloss: 0.633106
# [27]	valid_0's binary_logloss: 0.631793
# [28]	valid_0's binary_logloss: 0.630881
# [29]	valid_0's binary_logloss: 0.629125
# [30]	valid_0's binary_logloss: 0.628154
# [31]	valid_0's binary_logloss: 0.627507
# [32]	valid_0's binary_logloss: 0.626539
# [33]	valid_0's binary_logloss: 0.625508
# [34]	valid_0's binary_logloss: 0.623312
# [35]	valid_0's binary_logloss: 0.621519
# [36]	valid_0's binary_logloss: 0.62072
# [37]	valid_0's binary_logloss: 0.619626
# [38]	valid_0's binary_logloss: 0.619059
# [39]	valid_0's binary_logloss: 0.61798
# [40]	valid_0's binary_logloss: 0.617592
# [41]	valid_0's binary_logloss: 0.616384
# [42]	valid_0's binary_logloss: 0.615329
# [43]	valid_0's binary_logloss: 0.615151
# [44]	valid_0's binary_logloss: 0.613897
# [45]	valid_0's binary_logloss: 0.613276
# [46]	valid_0's binary_logloss: 0.611681
# [47]	valid_0's binary_logloss: 0.610623
# [48]	valid_0's binary_logloss: 0.609912
# [49]	valid_0's binary_logloss: 0.609132
# [50]	valid_0's binary_logloss: 0.60824
# ...
# [104]	valid_0's binary_logloss: 0.610188
# [105]	valid_0's binary_logloss: 0.610413
# [106]	valid_0's binary_logloss: 0.610268
# [107]	valid_0's binary_logloss: 0.610039
# [108]	valid_0's binary_logloss: 0.609973
# [109]	valid_0's binary_logloss: 0.609768
# [110]	valid_0's binary_logloss: 0.609977
# [111]	valid_0's binary_logloss: 0.609395
# [112]	valid_0's binary_logloss: 0.608445
# [113]	valid_0's binary_logloss: 0.608244
# [114]	valid_0's binary_logloss: 0.608367
# [115]	valid_0's binary_logloss: 0.608078
# [116]	valid_0's binary_logloss: 0.607997
# [117]	valid_0's binary_logloss: 0.608229
# [118]	valid_0's binary_logloss: 0.607787
# [119]	valid_0's binary_logloss: 0.607593
# [120]	valid_0's binary_logloss: 0.607435
# [121]	valid_0's binary_logloss: 0.606807
# [122]	valid_0's binary_logloss: 0.606951
# [123]	valid_0's binary_logloss: 0.607074
# [124]	valid_0's binary_logloss: 0.607052
# [125]	valid_0's binary_logloss: 0.606653
# [126]	valid_0's binary_logloss: 0.605643
# [127]	valid_0's binary_logloss: 0.60556
# [128]	valid_0's binary_logloss: 0.605393
# [129]	valid_0's binary_logloss: 0.605393
# [130]	valid_0's binary_logloss: 0.605433
# [131]	valid_0's binary_logloss: 0.60551
# [132]	valid_0's binary_logloss: 0.605624
# [133]	valid_0's binary_logloss: 0.605059
# [134]	valid_0's binary_logloss: 0.604848
# [135]	valid_0's binary_logloss: 0.604958
# [136]	valid_0's binary_logloss: 0.605112
# [137]	valid_0's binary_logloss: 0.604877
# [138]	valid_0's binary_logloss: 0.6048
# [139]	valid_0's binary_logloss: 0.605014
# [140]	valid_0's binary_logloss: 0.604769
# [141]	valid_0's binary_logloss: 0.605005
# [142]	valid_0's binary_logloss: 0.604936
# [143]	valid_0's binary_logloss: 0.60534
# [144]	valid_0's binary_logloss: 0.60522
# [145]	valid_0's binary_logloss: 0.604735
# [146]	valid_0's binary_logloss: 0.604461
# [147]	valid_0's binary_logloss: 0.603915
# [148]	valid_0's binary_logloss: 0.603545
# [149]	valid_0's binary_logloss: 0.603774
# [150]	valid_0's binary_logloss: 0.6038
# [151]	valid_0's binary_logloss: 0.604022
# [152]	valid_0's binary_logloss: 0.603888
# [153]	valid_0's binary_logloss: 0.603669
# [154]	valid_0's binary_logloss: 0.603669
# [155]	valid_0's binary_logloss: 0.603669
# [156]	valid_0's binary_logloss: 0.603669
# [157]	valid_0's binary_logloss: 0.603669
# [158]	valid_0's binary_logloss: 0.603669
# [159]	valid_0's binary_logloss: 0.603669
# [160]	valid_0's binary_logloss: 0.603669
# [161]	valid_0's binary_logloss: 0.603669
# [162]	valid_0's binary_logloss: 0.603669
# [163]	valid_0's binary_logloss: 0.603669
# [164]	valid_0's binary_logloss: 0.603669
# [165]	valid_0's binary_logloss: 0.603669
# [166]	valid_0's binary_logloss: 0.603669
# [167]	valid_0's binary_logloss: 0.603669
# [168]	valid_0's binary_logloss: 0.603669
# [169]	valid_0's binary_logloss: 0.603669
# [170]	valid_0's binary_logloss: 0.603669
# [171]	valid_0's binary_logloss: 0.603669
# [172]	valid_0's binary_logloss: 0.603669
# [173]	valid_0's binary_logloss: 0.603669
# [174]	valid_0's binary_logloss: 0.603669
# [175]	valid_0's binary_logloss: 0.603669
# [176]	valid_0's binary_logloss: 0.603669
# [177]	valid_0's binary_logloss: 0.603669
# [178]	valid_0's binary_logloss: 0.603669
# [179]	valid_0's binary_logloss: 0.603669
# [180]	valid_0's binary_logloss: 0.603669
# [181]	valid_0's binary_logloss: 0.603669
# [182]	valid_0's binary_logloss: 0.603669
# [183]	valid_0's binary_logloss: 0.603669
# [184]	valid_0's binary_logloss: 0.603669
# [185]	valid_0's binary_logloss: 0.603669
# [186]	valid_0's binary_logloss: 0.603669
# [187]	valid_0's binary_logloss: 0.603669
# [188]	valid_0's binary_logloss: 0.603669
# [189]	valid_0's binary_logloss: 0.603669
# [190]	valid_0's binary_logloss: 0.603669
# [191]	valid_0's binary_logloss: 0.603669
# [192]	valid_0's binary_logloss: 0.603669
# [193]	valid_0's binary_logloss: 0.603669
# [194]	valid_0's binary_logloss: 0.603669
# [195]	valid_0's binary_logloss: 0.603669
# [196]	valid_0's binary_logloss: 0.603669
# [197]	valid_0's binary_logloss: 0.603669
# [198]	valid_0's binary_logloss: 0.603669
# Early stopping, best iteration is:
# [148]	valid_0's binary_logloss: 0.603545
# [LightGBM] [Warning] min_gain_to_split is set=0.29880909621339424, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=0.29880909621339424
# [LightGBM] [Warning] feature_fraction is set=0.5291317097838137, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5291317097838137
# [LightGBM] [Warning] bagging_fraction is set=0.7026098408864507, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7026098408864507
# [LightGBM] [Warning] lambda_l2 is set=28, reg_lambda=0.0 will be ignored. Current value: lambda_l2=28
# [LightGBM] [Warning] lambda_l1 is set=16, reg_alpha=0.0 will be ignored. Current value: lambda_l1=16
# [1]	valid_0's binary_logloss: 0.688945
# Training until validation scores don't improve for 50 rounds
# [2]	valid_0's binary_logloss: 0.684321
# [3]	valid_0's binary_logloss: 0.680626
# [4]	valid_0's binary_logloss: 0.677314
# [5]	valid_0's binary_logloss: 0.674501
# [6]	valid_0's binary_logloss: 0.671776
# [7]	valid_0's binary_logloss: 0.669771
# [8]	valid_0's binary_logloss: 0.667
# [9]	valid_0's binary_logloss: 0.66428
# [10]	valid_0's binary_logloss: 0.661316
# [11]	valid_0's binary_logloss: 0.659401
# [12]	valid_0's binary_logloss: 0.658556
# [13]	valid_0's binary_logloss: 0.656707
# [14]	valid_0's binary_logloss: 0.655316
# [15]	valid_0's binary_logloss: 0.654065
# [16]	valid_0's binary_logloss: 0.652937
# [17]	valid_0's binary_logloss: 0.651473
# [18]	valid_0's binary_logloss: 0.649854
# [19]	valid_0's binary_logloss: 0.648356
# [20]	valid_0's binary_logloss: 0.646987
# [21]	valid_0's binary_logloss: 0.646202
# [22]	valid_0's binary_logloss: 0.64547
# [23]	valid_0's binary_logloss: 0.644048
# [24]	valid_0's binary_logloss: 0.642647
# [25]	valid_0's binary_logloss: 0.641189
# [26]	valid_0's binary_logloss: 0.640596
# [27]	valid_0's binary_logloss: 0.63948
# [28]	valid_0's binary_logloss: 0.638291
# [29]	valid_0's binary_logloss: 0.637303
# [30]	valid_0's binary_logloss: 0.636559
# [31]	valid_0's binary_logloss: 0.635842
# [32]	valid_0's binary_logloss: 0.634748
# [33]	valid_0's binary_logloss: 0.634382
# [34]	valid_0's binary_logloss: 0.633851
# [35]	valid_0's binary_logloss: 0.633026
# [36]	valid_0's binary_logloss: 0.631684
# [37]	valid_0's binary_logloss: 0.630979
# [38]	valid_0's binary_logloss: 0.630334
# [39]	valid_0's binary_logloss: 0.629511
# [40]	valid_0's binary_logloss: 0.628627
# [41]	valid_0's binary_logloss: 0.627979
# [42]	valid_0's binary_logloss: 0.626574
# [43]	valid_0's binary_logloss: 0.626041
# [44]	valid_0's binary_logloss: 0.62566
# [45]	valid_0's binary_logloss: 0.624758
# [46]	valid_0's binary_logloss: 0.623989
# [47]	valid_0's binary_logloss: 0.623345
# [48]	valid_0's binary_logloss: 0.62229
# [49]	valid_0's binary_logloss: 0.621721
# [50]	valid_0's binary_logloss: 0.62072
# [51]	valid_0's binary_logloss: 0.619967
# [52]	valid_0's binary_logloss: 0.619236
# [53]	valid_0's binary_logloss: 0.618597
# [54]	valid_0's binary_logloss: 0.617936
# [55]	valid_0's binary_logloss: 0.616786
# [56]	valid_0's binary_logloss: 0.616328
# [57]	valid_0's binary_logloss: 0.616225
# [58]	valid_0's binary_logloss: 0.615716
# [59]	valid_0's binary_logloss: 0.615453
# [60]	valid_0's binary_logloss: 0.614992
# [61]	valid_0's binary_logloss: 0.61474
# [62]	valid_0's binary_logloss: 0.61416
# [63]	valid_0's binary_logloss: 0.613495
# [64]	valid_0's binary_logloss: 0.612704
# [65]	valid_0's binary_logloss: 0.612011
# [66]	valid_0's binary_logloss: 0.611587
# [67]	valid_0's binary_logloss: 0.61102
# [68]	valid_0's binary_logloss: 0.6106
# [69]	valid_0's binary_logloss: 0.609848
# [70]	valid_0's binary_logloss: 0.609497
# [71]	valid_0's binary_logloss: 0.609154
# [72]	valid_0's binary_logloss: 0.608764
# [73]	valid_0's binary_logloss: 0.607746
# [74]	valid_0's binary_logloss: 0.606568
# [75]	valid_0's binary_logloss: 0.606225
# [76]	valid_0's binary_logloss: 0.605314
# [77]	valid_0's binary_logloss: 0.605145
# [78]	valid_0's binary_logloss: 0.604912
# [79]	valid_0's binary_logloss: 0.604489
# [80]	valid_0's binary_logloss: 0.603752
# [81]	valid_0's binary_logloss: 0.603452
# [82]	valid_0's binary_logloss: 0.603022
# [83]	valid_0's binary_logloss: 0.601973
# [84]	valid_0's binary_logloss: 0.601804
# [85]	valid_0's binary_logloss: 0.601646
# [86]	valid_0's binary_logloss: 0.601131
# [87]	valid_0's binary_logloss: 0.600529
# [88]	valid_0's binary_logloss: 0.599828
# [89]	valid_0's binary_logloss: 0.599854
# [90]	valid_0's binary_logloss: 0.599486
# [91]	valid_0's binary_logloss: 0.598615
# [92]	valid_0's binary_logloss: 0.598339
# [93]	valid_0's binary_logloss: 0.598252
# [94]	valid_0's binary_logloss: 0.597888
# [95]	valid_0's binary_logloss: 0.59776
# [96]	valid_0's binary_logloss: 0.597451
# [97]	valid_0's binary_logloss: 0.597254
# [98]	valid_0's binary_logloss: 0.596913
# [99]	valid_0's binary_logloss: 0.59641
# [100]	valid_0's binary_logloss: 0.595957
# [101]	valid_0's binary_logloss: 0.595714
# [102]	valid_0's binary_logloss: 0.594958
# [103]	valid_0's binary_logloss: 0.594533
# [104]	valid_0's binary_logloss: 0.594296
# [105]	valid_0's binary_logloss: 0.593858
# [106]	valid_0's binary_logloss: 0.593219
# [107]	valid_0's binary_logloss: 0.592895
# [108]	valid_0's binary_logloss: 0.592454
# [109]	valid_0's binary_logloss: 0.592174
# [110]	valid_0's binary_logloss: 0.592029
# [111]	valid_0's binary_logloss: 0.591797
# [112]	valid_0's binary_logloss: 0.591466
# [113]	valid_0's binary_logloss: 0.591163
# [114]	valid_0's binary_logloss: 0.590736
# [115]	valid_0's binary_logloss: 0.590411
# [116]	valid_0's binary_logloss: 0.59064
# [117]	valid_0's binary_logloss: 0.590322
# [118]	valid_0's binary_logloss: 0.590175
# [119]	valid_0's binary_logloss: 0.589869
# [120]	valid_0's binary_logloss: 0.589213
# [121]	valid_0's binary_logloss: 0.589048
# [122]	valid_0's binary_logloss: 0.588639
# [123]	valid_0's binary_logloss: 0.588617
# [124]	valid_0's binary_logloss: 0.588013
# [125]	valid_0's binary_logloss: 0.587799
# [126]	valid_0's binary_logloss: 0.58735
# [127]	valid_0's binary_logloss: 0.58718
# [128]	valid_0's binary_logloss: 0.586846
# [129]	valid_0's binary_logloss: 0.586784
# [130]	valid_0's binary_logloss: 0.58651
# [131]	valid_0's binary_logloss: 0.586141
# [132]	valid_0's binary_logloss: 0.586336
# [133]	valid_0's binary_logloss: 0.585761
# [134]	valid_0's binary_logloss: 0.585196
# [135]	valid_0's binary_logloss: 0.584929
# [136]	valid_0's binary_logloss: 0.584894
# [137]	valid_0's binary_logloss: 0.584508
# [138]	valid_0's binary_logloss: 0.584421
# [139]	valid_0's binary_logloss: 0.584447
# [140]	valid_0's binary_logloss: 0.584002
# [141]	valid_0's binary_logloss: 0.583672
# [142]	valid_0's binary_logloss: 0.583613
# [143]	valid_0's binary_logloss: 0.583145
# [144]	valid_0's binary_logloss: 0.583184
# [145]	valid_0's binary_logloss: 0.582929
# [146]	valid_0's binary_logloss: 0.582499
# [147]	valid_0's binary_logloss: 0.582332
# [148]	valid_0's binary_logloss: 0.582225
# [149]	valid_0's binary_logloss: 0.581958
# [150]	valid_0's binary_logloss: 0.58128
# [151]	valid_0's binary_logloss: 0.581196
# [152]	valid_0's binary_logloss: 0.58107
# [153]	valid_0's binary_logloss: 0.580951
# [154]	valid_0's binary_logloss: 0.580935
# [155]	valid_0's binary_logloss: 0.580739
# [156]	valid_0's binary_logloss: 0.580453
# [157]	valid_0's binary_logloss: 0.580361
# [158]	valid_0's binary_logloss: 0.580123
# [159]	valid_0's binary_logloss: 0.579955
# [160]	valid_0's binary_logloss: 0.579871
# [161]	valid_0's binary_logloss: 0.579428
# [162]	valid_0's binary_logloss: 0.579477
# [163]	valid_0's binary_logloss: 0.579548
# [164]	valid_0's binary_logloss: 0.5793
# [165]	valid_0's binary_logloss: 0.579051
# [166]	valid_0's binary_logloss: 0.579068
# [167]	valid_0's binary_logloss: 0.578825
# [168]	valid_0's binary_logloss: 0.578722
# [169]	valid_0's binary_logloss: 0.578852
# [170]	valid_0's binary_logloss: 0.578516
# [171]	valid_0's binary_logloss: 0.578452
# [172]	valid_0's binary_logloss: 0.578243
# [173]	valid_0's binary_logloss: 0.578079
# [174]	valid_0's binary_logloss: 0.577899
# [175]	valid_0's binary_logloss: 0.577555
# [176]	valid_0's binary_logloss: 0.577395
# [177]	valid_0's binary_logloss: 0.57727
# [178]	valid_0's binary_logloss: 0.57727
# [179]	valid_0's binary_logloss: 0.577548
# [180]	valid_0's binary_logloss: 0.577515
# [181]	valid_0's binary_logloss: 0.576959
# [182]	valid_0's binary_logloss: 0.576691
# [183]	valid_0's binary_logloss: 0.576825
# [184]	valid_0's binary_logloss: 0.576701
# [185]	valid_0's binary_logloss: 0.5765
# [186]	valid_0's binary_logloss: 0.576247
# [187]	valid_0's binary_logloss: 0.57614
# [188]	valid_0's binary_logloss: 0.576242
# [189]	valid_0's binary_logloss: 0.576194
# [190]	valid_0's binary_logloss: 0.576324
# [191]	valid_0's binary_logloss: 0.57601
# [192]	valid_0's binary_logloss: 0.57566
# [193]	valid_0's binary_logloss: 0.575607
# [194]	valid_0's binary_logloss: 0.575619
# [195]	valid_0's binary_logloss: 0.575413
# [196]	valid_0's binary_logloss: 0.575138
# [197]	valid_0's binary_logloss: 0.575046
# [198]	valid_0's binary_logloss: 0.57508
# [199]	valid_0's binary_logloss: 0.57534
# [200]	valid_0's binary_logloss: 0.575366
# Did not meet early stopping. Best iteration is:
# [197]	valid_0's binary_logloss: 0.575046
# (20428, 105)
# 16342 4086
# (20428, 105)
# 16342 4086
# [LightGBM] [Warning] min_gain_to_split is set=0.29880909621339424, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=0.29880909621339424
# [LightGBM] [Warning] feature_fraction is set=0.5291317097838137, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5291317097838137
# [LightGBM] [Warning] bagging_fraction is set=0.7026098408864507, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7026098408864507
# [LightGBM] [Warning] lambda_l2 is set=28, reg_lambda=0.0 will be ignored. Current value: lambda_l2=28
# [LightGBM] [Warning] lambda_l1 is set=16, reg_alpha=0.0 will be ignored. Current value: lambda_l1=16
# (20428, 105)
# 16342 4086
# [LightGBM] [Warning] min_gain_to_split is set=0.29880909621339424, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=0.29880909621339424
# [LightGBM] [Warning] feature_fraction is set=0.5291317097838137, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5291317097838137
# [LightGBM] [Warning] bagging_fraction is set=0.7026098408864507, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7026098408864507
# [LightGBM] [Warning] lambda_l2 is set=28, reg_lambda=0.0 will be ignored. Current value: lambda_l2=28
# [LightGBM] [Warning] lambda_l1 is set=16, reg_alpha=0.0 will be ignored. Current value: lambda_l1=16
# (20428, 105)
# 16343 4085
# [LightGBM] [Warning] min_gain_to_split is set=0.29880909621339424, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=0.29880909621339424
# [LightGBM] [Warning] feature_fraction is set=0.5291317097838137, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5291317097838137
# [LightGBM] [Warning] bagging_fraction is set=0.7026098408864507, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7026098408864507
# [LightGBM] [Warning] lambda_l2 is set=28, reg_lambda=0.0 will be ignored. Current value: lambda_l2=28
# [LightGBM] [Warning] lambda_l1 is set=16, reg_alpha=0.0 will be ignored. Current value: lambda_l1=16
# (20428, 105)
# 16343 4085
# [LightGBM] [Warning] min_gain_to_split is set=0.29880909621339424, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=0.29880909621339424
# [LightGBM] [Warning] feature_fraction is set=0.5291317097838137, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5291317097838137
# [LightGBM] [Warning] bagging_fraction is set=0.7026098408864507, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7026098408864507
# [LightGBM] [Warning] lambda_l2 is set=28, reg_lambda=0.0 will be ignored. Current value: lambda_l2=28
# [LightGBM] [Warning] lambda_l1 is set=16, reg_alpha=0.0 will be ignored. Current value: lambda_l1=16
# roc取线: (auc值0.8913247723248012)
# ------------------------------------------------------------
# ks曲线: (ks值0.6335835096084605)
# roc取线: (auc值0.6846212877558279)
# ------------------------------------------------------------
# ks曲线: (ks值0.27274045495775284)
# roc取线: (auc值0.6298839691896773)
# ------------------------------------------------------------
# ks曲线: (ks值0.19261287479372002)

# %% [markdown]
# 模型应用
#
# 生成评分卡、评分转换、风险等分表。

# %%
class BuildScoreCard(object):
    def __init__(self, model, feats, target, bin_woe_df):
        self.best_model=model
        self.feats = feats
        self.target = target
        self.bin_iv_woe_df = bin_woe_df

    def _score_params(self, base_point=600, odds=1/20, PDO=20):
        """
        给定基准分数、翻倍分数、PDO
        确定转换参数A、B
        """
        B = PDO/np.log(2)
        A = base_point + B*np.log(odds)
        print("(信用分)评分卡base_point:{0},odds:{1},PDO:{2}".format(base_point,odds,PDO))
        return A,B

    def build_score_card(self):
        """根据训练好的模型构造评分卡"""
        # 假设 Odds 在 1:60 时对应的参考分值为 600 分, 分值调整刻度 PDO 为 20, 则计算得到分值转化的参数 B = 28.85, A= 481.86。
        # score = A - B*log(p/(1-p))
        # 提取入模变量的权重
        model_params = list(self.feats)
        model_params.append('intercept')
        weight_value = list(self.best_model.coef_.flatten())  # 系数
        weight_value.extend(list(self.best_model.intercept_))  # 截距
        dict_params = dict(zip(model_params,weight_value))
        # 基准分
        params_A,params_B = self._score_params(base_point=600, odds=1/20, PDO=20)
        base_points = round(params_A - params_B * dict_params['intercept']) # 基准分，已包含截距
        print("基准分:{0}，已包含截距".format(base_points))
        # 样本得分转换
        x_features_bin_score = self.bin_iv_woe_df[self.bin_iv_woe_df['feature'].isin(self.feats)][['feature','bin','woe']]
        x_features_bin_score = pd.merge(
            x_features_bin_score
            ,pd.Series(dict_params,name='weight').to_frame()
            ,how='left',left_on='feature',right_index=True
            )
        x_features_bin_score['score'] = round(-params_B*x_features_bin_score['woe']*x_features_bin_score['weight'])
        base_score = {'feature':'base_points', 'bin':np.nan, 'woe':np.nan, 'weight':np.nan, 'score':base_points}
        x_features_bin_score = x_features_bin_score.append(base_score, ignore_index=True)
        
        self.score_card = x_features_bin_score
        self.base_score = base_points
        self.score_card_params_A,self.score_card_params_B = params_A,params_B

    def _sample_score(self, df):
        """
        对数据集进行打分，并验证分数的风险识别能力
        df已经过woe转换
        """
        # dataframe转换成字典，提高检索速度
        # dict_bin_score = dict(self.score_card.groupby('feature')[['woe','score']].apply(lambda x:dict(zip(x['woe'],x['score']))))
        for feat in self.feats:
            woe_score = self.score_card[self.score_card['feature']==feat][['woe', 'score']]
            transformed = np.zeros(len(df[feat]))
            for id,row in woe_score.iterrows():
                mask = (df[feat]==row['woe'])
                transformed[mask] = row['score']
            df.loc[:, feat] = transformed
        df['model_score'] = df[self.feats].sum(axis=1) + self.base_score
        return df
        
    def use_model_score(self, df):
        """信用分风险等分表"""
        score_df = self._sample_score(df)
        total_size = score_df[self.target].count()
        total_bad = score_df[self.target].sum()
        total_bad_rate = total_bad/total_size

        score_df['score_bin'] = pd.qcut(score_df['model_score'], q=20, duplicates='drop')
        cols = ['model_score','score_bin',self.target]
        bin_df = score_df[cols].groupby('score_bin')
        woe_df = pd.DataFrame(bin_df.size(), columns=['total'])
        woe_df['bad'] = bin_df[self.target].sum()
        woe_df['good'] = woe_df['total']-woe_df['bad']
        woe_df['bad_rate'] = woe_df['bad']/woe_df['total']
        woe_df['cum_total'] = woe_df['total'].cumsum()
        woe_df['cum_bad'] = woe_df['bad'].cumsum()
        woe_df['lift'] = woe_df['cum_bad']/woe_df['cum_total']/total_bad_rate
        
        return woe_df,score_df[['target','model_score','score_bin']]

# %%
score_card = BuildScoreCard(auto_ml.best_model, feat_selector.feats, feat_selector.target, feat_selector.bin_iv_woe_df)
score_card.build_score_card()
model_score_bin_df, scored_df = score_card.use_model_score(train.copy())
model_score_bin_df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/aman/Documents/2个人征信评分模型/解决方案-code/auto_score/model_score.ipynb Cell 18 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/aman/Documents/2%E4%B8%AA%E4%BA%BA%E5%BE%81%E4%BF%A1%E8%AF%84%E5%88%86%E6%A8%A1%E5%9E%8B/%E8%A7%A3%E5%86%B3%E6%96%B9%E6%A1%88-code/auto_score/model_score.ipynb#X23sZmlsZQ%3D%3D?line=0'>1</a> score_card = BuildScoreCard(auto_ml.best_model, feat_selector.feats, feat_selector.target, feat_selector.bin_iv_woe_df)
# ----> <a href='vscode-notebook-cell:/Users/aman/Documents/2%E4%B8%AA%E4%BA%BA%E5%BE%81%E4%BF%A1%E8%AF%84%E5%88%86%E6%A8%A1%E5%9E%8B/%E8%A7%A3%E5%86%B3%E6%96%B9%E6%A1%88-code/auto_score/model_score.ipynb#X23sZmlsZQ%3D%3D?line=1'>2</a> score_card.build_score_card()
#       <a href='vscode-notebook-cell:/Users/aman/Documents/2%E4%B8%AA%E4%BA%BA%E5%BE%81%E4%BF%A1%E8%AF%84%E5%88%86%E6%A8%A1%E5%9E%8B/%E8%A7%A3%E5%86%B3%E6%96%B9%E6%A1%88-code/auto_score/model_score.ipynb#X23sZmlsZQ%3D%3D?line=2'>3</a> model_score_bin_df, scored_df = score_card.use_model_score(train.copy())
#       <a href='vscode-notebook-cell:/Users/aman/Documents/2%E4%B8%AA%E4%BA%BA%E5%BE%81%E4%BF%A1%E8%AF%84%E5%88%86%E6%A8%A1%E5%9E%8B/%E8%A7%A3%E5%86%B3%E6%96%B9%E6%A1%88-code/auto_score/model_score.ipynb#X23sZmlsZQ%3D%3D?line=3'>4</a> model_score_bin_df
#
# /Users/aman/Documents/2个人征信评分模型/解决方案-code/auto_score/model_score.ipynb Cell 18 in BuildScoreCard.build_score_card(self)
#      <a href='vscode-notebook-cell:/Users/aman/Documents/2%E4%B8%AA%E4%BA%BA%E5%BE%81%E4%BF%A1%E8%AF%84%E5%88%86%E6%A8%A1%E5%9E%8B/%E8%A7%A3%E5%86%B3%E6%96%B9%E6%A1%88-code/auto_score/model_score.ipynb#X23sZmlsZQ%3D%3D?line=22'>23</a> model_params = list(self.feats)
#      <a href='vscode-notebook-cell:/Users/aman/Documents/2%E4%B8%AA%E4%BA%BA%E5%BE%81%E4%BF%A1%E8%AF%84%E5%88%86%E6%A8%A1%E5%9E%8B/%E8%A7%A3%E5%86%B3%E6%96%B9%E6%A1%88-code/auto_score/model_score.ipynb#X23sZmlsZQ%3D%3D?line=23'>24</a> model_params.append('intercept')
# ---> <a href='vscode-notebook-cell:/Users/aman/Documents/2%E4%B8%AA%E4%BA%BA%E5%BE%81%E4%BF%A1%E8%AF%84%E5%88%86%E6%A8%A1%E5%9E%8B/%E8%A7%A3%E5%86%B3%E6%96%B9%E6%A1%88-code/auto_score/model_score.ipynb#X23sZmlsZQ%3D%3D?line=24'>25</a> weight_value = list(self.best_model.coef_.flatten())  # 系数
#      <a href='vscode-notebook-cell:/Users/aman/Documents/2%E4%B8%AA%E4%BA%BA%E5%BE%81%E4%BF%A1%E8%AF%84%E5%88%86%E6%A8%A1%E5%9E%8B/%E8%A7%A3%E5%86%B3%E6%96%B9%E6%A1%88-code/auto_score/model_score.ipynb#X23sZmlsZQ%3D%3D?line=25'>26</a> weight_value.extend(list(self.best_model.intercept_))  # 截距
#      <a href='vscode-notebook-cell:/Users/aman/Documents/2%E4%B8%AA%E4%BA%BA%E5%BE%81%E4%BF%A1%E8%AF%84%E5%88%86%E6%A8%A1%E5%9E%8B/%E8%A7%A3%E5%86%B3%E6%96%B9%E6%A1%88-code/auto_score/model_score.ipynb#X23sZmlsZQ%3D%3D?line=26'>27</a> dict_params = dict(zip(model_params,weight_value))
#
# AttributeError: 'LGBMClassifier' object has no attribute 'coef_'

# %%
scored_df.groupby('target').agg({'model_score':'mean'})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/aman/Documents/2个人征信评分模型/解决方案-code/auto_score/model_score.ipynb Cell 19 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/aman/Documents/2%E4%B8%AA%E4%BA%BA%E5%BE%81%E4%BF%A1%E8%AF%84%E5%88%86%E6%A8%A1%E5%9E%8B/%E8%A7%A3%E5%86%B3%E6%96%B9%E6%A1%88-code/auto_score/model_score.ipynb#X24sZmlsZQ%3D%3D?line=0'>1</a> scored_df.groupby('target').agg({'model_score':'mean'})
#
# NameError: name 'scored_df' is not defined

# %%
class AutoModelScore(object):
    def _learning_rate_010_decay_power_0995(current_iter):
        base_learning_rate = 0.1
        lr = base_learning_rate  * np.power(.995, current_iter)
        return lr if lr > 1e-3 else 1e-3
        
    def hyper_para_search(self, set_params, search_params, n_HP_points_to_test):
        """超参数网格搜索"""
        clf = LGBMClassifier(**set_params)
        # sklearn的RandomizedSearchCV内部通过并行来提速。
        gs = RandomizedSearchCV(
                estimator=clf, 
                param_distributions=search_params, 
                n_iter=n_HP_points_to_test,
                scoring='roc_auc',
                cv=5,
                verbose=1,
                # refit=True,    # default True
                random_state=2021,
                n_jobs=2,
                )
        gs.fit(self.train_x, self.train_y, eval_set=(self.test_x, self.test_y))
        # print('Best score reached:', gs.best_score_)
        # print('Best params: ', gs.best_params_)
        best_params = gs.best_estimator_.get_params()
        # opt_parameters = {'colsample_bytree': 0.9234, 'min_child_samples': 399, 'min_child_weight': 0.1, 'num_leaves': 13, 'reg_alpha': 2, 'reg_lambda': 5, 'subsample': 0.855}
        # clf_final = LGBMClassifier(**gs.best_estimator_.get_params())
        # or
        # clf_final = LGBMClassifier(**clf.get_params())
        # or
        # clf_final.set_params(**opt_parameters)
        # clf_final.fit(X_train, y_train, **fit_params, callbacks=[lgb.reset_parameter(learning_rate=learning_rate_010_decay_power_0995)])

    def _fit(self, set_params):
        folds = KFold(n_splits=5, shuffle=True, random_state=2021)
        nflod_train_preds = []
        nflod_valid_preds = np.zeros(self.train_x.shape[0])
        oof_preds = np.zeros(self.test_x.shape[0])
        # feature_importance_df = pd.DataFrame()
        for n_fold, (train_idx, valid_idx) in enumerate(folds.split(self.train_x)):
            train_x, train_y = self.train_x.iloc[train_idx], self.train_y.iloc[train_idx]
            valid_x, valid_y = self.train_x.iloc[valid_idx], self.train_y.iloc[valid_idx]
            
            self.model = LGBMClassifier(**set_params)
            self.model.fit(train_x, train_y, eval_set=(valid_x, valid_y), eval_metric='auc', verbose=False, early_stopping_rounds=200)
            train_pred = self.model.predict_proba(train_x, num_iteration=self.model.best_iteration_)[:, 1]
            nflod_valid_preds[valid_idx] = self.model.predict_proba(valid_x, num_iteration=self.model.best_iteration_)[:, 1]
            train_auc = roc_auc_score(train_y, train_pred)
            nflod_train_preds.append(train_auc)
            valid_auc = roc_auc_score(self.train_y, nflod_valid_preds)
            # print('Fold %2d train AUC : %.6f, valid AUC : %.6f' % (n_fold + 1, train_auc, valid_auc))
            oof_preds += self.model.predict_proba(self.test_x, num_iteration=self.model.best_iteration_)[:, 1]/folds.n_splits
        print('avg train AUC: %.6f, valid AUC: %.6f' % (np.mean(nflod_train_preds), valid_auc))
        print('test auc: %.6f' % roc_auc_score(self.test_y, oof_preds))
        del train_x, train_y, valid_x, valid_y
        gc.collect()

    def fit(self, set_params, search_params=None, n_HP_points_to_test=100):
        if search_params is None:
            self._fit(set_params)
        else:
            set_params = self.hyper_para_search(set_params, search_params, n_HP_points_to_test)
            self._fit(set_params)
    
    # def _has_fit(self):
    #     return hasattr(self, 'model')

    def metrics():
        pass

    def test_transform(self,test_data):
        return test_data[self.choiced_feature]

    def prob_to_result(self, threshold):
        pass

    # @available_if(_has_fit)
    def predict(self, test_df):
        if hasattr(self, 'model'):
            test_transformed = self.test_transform(test_df)
            test_pred = self.model.predict_proba(test_transformed, num_iteration=self.model.best_iteration_)[:,1]
            return test_pred
        else:
            print('do not have fitted model!!!')

    def save_model(self):
        joblib.dump(self.automl.model, './data/output/lgbmchassfier.pkl')
    
    def load_fitted_model(self):
        self.model = joblib.load('./data/output/lgbmchassfier.pkl')

# %%
# PROJECT_ROOT_DIR = "./data"
# IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "output")
# os.makedirs(IMAGES_PATH, exist_ok=True)
